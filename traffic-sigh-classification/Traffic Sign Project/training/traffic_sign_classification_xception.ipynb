# %%
# !python -m pip install -qq kaggle

# %%
# %%bash
# mkdir ~/.kaggle
# cp kaggle.json ~/.kaggle/
# chmod 600 /root/.kaggle/kaggle.json
# kaggle datasets download sarangdilipjodh/indian-traffic-signs-prediction85-classes
# unzip -qq "/content/indian-traffic-signs-prediction85-classes.zip"
# rm -rf "/content/sample_data"
# Out:
# Downloading indian-traffic-signs-prediction85-classes.zip to /content
# 100%|██████████| 1.13G/1.13G [00:10<00:00, 115MB/s]

# %%
#import libraries
import os
import string
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from matplotlib import pyplot as plt
from PIL import Image
import re

# %%
# Traning classes
training_classes=os.listdir('/content/traffic_sign_classification_dataset/train')
print('Total classes:',len(training_classes))
print('Class names:',training_classes)
#clean class names
training_classes_clean=[re.sub('[^A-Za-z0-9 ]',' ',class_)for class_ in training_classes]
training_classes_clean=[re.sub('[ ]+','_',class_).casefold() for class_ in training_classes_clean]
print('Cleaned class names:',training_classes_clean)
#rename classes name with clean class names
for old_name,new_name in zip(training_classes,training_classes_clean):
  os.rename(os.path.join('/content/traffic_sign_classification_dataset/train',old_name),
            os.path.join('/content/traffic_sign_classification_dataset/train',new_name))
# Out:
# Total classes: 85
# Class names: ['HUMP_OR_ROUGH_ROAD', 'T_INTERSECTION', 'SPEED_LIMIT_30', 'AXLE_LOAD_LIMIT', 'PEDESTRIAN_PROHIBITED', 'BULLOCK_PROHIBITED', 'LEFT_HAND_CURVE', 'Y_INTERSECTION', 'COMPULSARY_KEEP_RIGHT', 'NARROW_BRIDGE', 'ROAD_WIDENS_AHEAD', 'COMPULSARY_TURN_LEFT_AHEAD', 'PEDESTRIAN_CROSSING', 'STAGGERED_INTERSECTION', 'RIGHT_REVERSE_BEND', 'SPEED_LIMIT_50', 'TRAFFIC_SIGNAL', 'HORN_PROHIBITED', 'COMPULSARY_TURN_LEFT', 'COMPULSARY_TURN_RIGHT_AHEAD', 'FERRY', 'GAP_IN_MEDIAN', 'CYCLE_PROHIBITED', 'CATTLE', 'COMPULSARY_SOUND_HORN', 'COMPULSARY_KEEP_LEFT', 'RIGHT_TURN_PROHIBITED', 'TONGA_PROHIBITED', 'GUARDED_LEVEL_CROSSING', 'OVERTAKING_PROHIBITED', 'BARRIER_AHEAD', 'BULLOCK_AND_HANDCART_PROHIBITED', 'DANGEROUS_DIP', 'STEEP_ASCENT', 'COMPULSARY_TURN_RIGHT', 'LENGTH_LIMIT', 'LEFT_TURN_PROHIBITED', 'CROSS_ROAD', 'SLIPPERY_ROAD', 'COMPULSARY_AHEAD_OR_TURN_RIGHT', 'RIGHT_HAND_CURVE', 'LOAD_LIMIT', 'RIGHT_HAIR_PIN_BEND', 'ALL_MOTOR_VEHICLE_PROHIBITED', 'PRIORITY_FOR_ONCOMING_VEHICLES', 'NO_STOPPING_OR_STANDING', 'DIRECTION', 'COMPULSARY_AHEAD_OR_TURN_LEFT', 'RESTRICTION_ENDS', 'TRUCK_PROHIBITED', 'SPEED_LIMIT_20', 'STOP', 'COMPULSARY_CYCLE_TRACK', 'GIVE_WAY', 'FALLING_ROCKS', 'SCHOOL_AHEAD', 'SPEED_LIMIT_40', 'QUAY_SIDE_OR_RIVER_BANK', 'STEEP_DESCENT', 'MEN_AT_WORK', 'LEFT_REVERSE_BEND', 'SPEED_LIMIT_5', 'HANDCART_PROHIBITED', 'LOOSE_GRAVEL', 'UNGUARDED_LEVEL_CROSSING', 'COMPULSARY_AHEAD', 'WIDTH_LIMIT', 'NO_ENTRY', 'SPEED_LIMIT_60', 'ROUNDABOUT', 'SPEED_LIMIT_80', 'COMPULSARY_MINIMUM_SPEED', 'PASS_EITHER_SIDE', 'HEIGHT_LIMIT', 'NARROW_ROAD_AHEAD', 'SIDE_ROAD_RIGHT', 'SPEED_LIMIT_15', 'LEFT_HAIR_PIN_BEND', 'NO_PARKING', 'SIDE_ROAD_LEFT', 'SPEED_LIMIT_70', 'TURN_RIGHT', 'STRAIGHT_PROHIBITED', 'U_TURN_PROHIBITED', 'CYCLE_CROSSING']
# Cleaned class names: ['hump_or_rough_road', 't_intersection', 'speed_limit_30', 'axle_load_limit', 'pedestrian_prohibited', 'bullock_prohibited', 'left_hand_curve', 'y_intersection', 'compulsary_keep_right', 'narrow_bridge', 'road_widens_ahead', 'compulsary_turn_left_ahead', 'pedestrian_crossing', 'staggered_intersection', 'right_reverse_bend', 'speed_limit_50', 'traffic_signal', 'horn_prohibited', 'compulsary_turn_left', 'compulsary_turn_right_ahead', 'ferry', 'gap_in_median', 'cycle_prohibited', 'cattle', 'compulsary_sound_horn', 'compulsary_keep_left', 'right_turn_prohibited', 'tonga_prohibited', 'guarded_level_crossing', 'overtaking_prohibited', 'barrier_ahead', 'bullock_and_handcart_prohibited', 'dangerous_dip', 'steep_ascent', 'compulsary_turn_right', 'length_limit', 'left_turn_prohibited', 'cross_road', 'slippery_road', 'compulsary_ahead_or_turn_right', 'right_hand_curve', 'load_limit', 'right_hair_pin_bend', 'all_motor_vehicle_prohibited', 'priority_for_oncoming_vehicles', 'no_stopping_or_standing', 'direction', 'compulsary_ahead_or_turn_left', 'restriction_ends', 'truck_prohibited', 'speed_limit_20', 'stop', 'compulsary_cycle_track', 'give_way', 'falling_rocks', 'school_ahead', 'speed_limit_40', 'quay_side_or_river_bank', 'steep_descent', 'men_at_work', 'left_reverse_bend', 'speed_limit_5', 'handcart_prohibited', 'loose_gravel', 'unguarded_level_crossing', 'compulsary_ahead', 'width_limit', 'no_entry', 'speed_limit_60', 'roundabout', 'speed_limit_80', 'compulsary_minimum_speed', 'pass_either_side', 'height_limit', 'narrow_road_ahead', 'side_road_right', 'speed_limit_15', 'left_hair_pin_bend', 'no_parking', 'side_road_left', 'speed_limit_70', 'turn_right', 'straight_prohibited', 'u_turn_prohibited', 'cycle_crossing']

# %%
# Testing classes
testing_classes=os.listdir('/content/traffic_sign_classification_dataset/test')
print('Total classes:',len(testing_classes))
print('Class names:',testing_classes)
#clean class names
testing_classes_clean=[re.sub('[^A-Za-z0-9 ]',' ',class_)for class_ in testing_classes]
testing_classes_clean=[re.sub('[ ]+','_',class_).casefold() for class_ in testing_classes_clean]
print('Cleaned class names:',testing_classes_clean)
#rename classes name with clean class names
for old_name,new_name in zip(testing_classes,testing_classes_clean):
  os.rename(os.path.join('/content/traffic_sign_classification_dataset/test',old_name),
            os.path.join('/content/traffic_sign_classification_dataset/test',new_name))
# Out:
# Total classes: 85
# Class names: ['HUMP_OR_ROUGH_ROAD', 'T_INTERSECTION', 'SPEED_LIMIT_30', 'AXLE_LOAD_LIMIT', 'PEDESTRIAN_PROHIBITED', 'BULLOCK_PROHIBITED', 'LEFT_HAND_CURVE', 'Y_INTERSECTION', 'COMPULSARY_KEEP_RIGHT', 'NARROW_BRIDGE', 'ROAD_WIDENS_AHEAD', 'COMPULSARY_TURN_LEFT_AHEAD', 'PEDESTRIAN_CROSSING', 'STAGGERED_INTERSECTION', 'RIGHT_REVERSE_BEND', 'SPEED_LIMIT_50', 'TRAFFIC_SIGNAL', 'HORN_PROHIBITED', 'COMPULSARY_TURN_LEFT', 'COMPULSARY_TURN_RIGHT_AHEAD', 'FERRY', 'GAP_IN_MEDIAN', 'CYCLE_PROHIBITED', 'CATTLE', 'COMPULSARY_SOUND_HORN', 'COMPULSARY_KEEP_LEFT', 'RIGHT_TURN_PROHIBITED', 'TONGA_PROHIBITED', 'GUARDED_LEVEL_CROSSING', 'OVERTAKING_PROHIBITED', 'BARRIER_AHEAD', 'BULLOCK_AND_HANDCART_PROHIBITED', 'DANGEROUS_DIP', 'STEEP_ASCENT', 'COMPULSARY_TURN_RIGHT', 'LENGTH_LIMIT', 'LEFT_TURN_PROHIBITED', 'CROSS_ROAD', 'SLIPPERY_ROAD', 'COMPULSARY_AHEAD_OR_TURN_RIGHT', 'RIGHT_HAND_CURVE', 'LOAD_LIMIT', 'RIGHT_HAIR_PIN_BEND', 'ALL_MOTOR_VEHICLE_PROHIBITED', 'PRIORITY_FOR_ONCOMING_VEHICLES', 'NO_STOPPING_OR_STANDING', 'DIRECTION', 'COMPULSARY_AHEAD_OR_TURN_LEFT', 'RESTRICTION_ENDS', 'TRUCK_PROHIBITED', 'SPEED_LIMIT_20', 'STOP', 'COMPULSARY_CYCLE_TRACK', 'GIVE_WAY', 'FALLING_ROCKS', 'SCHOOL_AHEAD', 'SPEED_LIMIT_40', 'QUAY_SIDE_OR_RIVER_BANK', 'STEEP_DESCENT', 'MEN_AT_WORK', 'LEFT_REVERSE_BEND', 'SPEED_LIMIT_5', 'HANDCART_PROHIBITED', 'LOOSE_GRAVEL', 'UNGUARDED_LEVEL_CROSSING', 'COMPULSARY_AHEAD', 'WIDTH_LIMIT', 'NO_ENTRY', 'SPEED_LIMIT_60', 'ROUNDABOUT', 'SPEED_LIMIT_80', 'COMPULSARY_MINIMUM_SPEED', 'PASS_EITHER_SIDE', 'HEIGHT_LIMIT', 'NARROW_ROAD_AHEAD', 'SIDE_ROAD_RIGHT', 'SPEED_LIMIT_15', 'LEFT_HAIR_PIN_BEND', 'NO_PARKING', 'SIDE_ROAD_LEFT', 'SPEED_LIMIT_70', 'TURN_RIGHT', 'STRAIGHT_PROHIBITED', 'U_TURN_PROHIBITED', 'CYCLE_CROSSING']
# Cleaned class names: ['hump_or_rough_road', 't_intersection', 'speed_limit_30', 'axle_load_limit', 'pedestrian_prohibited', 'bullock_prohibited', 'left_hand_curve', 'y_intersection', 'compulsary_keep_right', 'narrow_bridge', 'road_widens_ahead', 'compulsary_turn_left_ahead', 'pedestrian_crossing', 'staggered_intersection', 'right_reverse_bend', 'speed_limit_50', 'traffic_signal', 'horn_prohibited', 'compulsary_turn_left', 'compulsary_turn_right_ahead', 'ferry', 'gap_in_median', 'cycle_prohibited', 'cattle', 'compulsary_sound_horn', 'compulsary_keep_left', 'right_turn_prohibited', 'tonga_prohibited', 'guarded_level_crossing', 'overtaking_prohibited', 'barrier_ahead', 'bullock_and_handcart_prohibited', 'dangerous_dip', 'steep_ascent', 'compulsary_turn_right', 'length_limit', 'left_turn_prohibited', 'cross_road', 'slippery_road', 'compulsary_ahead_or_turn_right', 'right_hand_curve', 'load_limit', 'right_hair_pin_bend', 'all_motor_vehicle_prohibited', 'priority_for_oncoming_vehicles', 'no_stopping_or_standing', 'direction', 'compulsary_ahead_or_turn_left', 'restriction_ends', 'truck_prohibited', 'speed_limit_20', 'stop', 'compulsary_cycle_track', 'give_way', 'falling_rocks', 'school_ahead', 'speed_limit_40', 'quay_side_or_river_bank', 'steep_descent', 'men_at_work', 'left_reverse_bend', 'speed_limit_5', 'handcart_prohibited', 'loose_gravel', 'unguarded_level_crossing', 'compulsary_ahead', 'width_limit', 'no_entry', 'speed_limit_60', 'roundabout', 'speed_limit_80', 'compulsary_minimum_speed', 'pass_either_side', 'height_limit', 'narrow_road_ahead', 'side_road_right', 'speed_limit_15', 'left_hair_pin_bend', 'no_parking', 'side_road_left', 'speed_limit_70', 'turn_right', 'straight_prohibited', 'u_turn_prohibited', 'cycle_crossing']

# %%
from tensorflow.python.ops.gen_batch_ops import batch
#load dataset - train,test and valid
train=tf.keras.utils.image_dataset_from_directory('/content/traffic_sign_classification_dataset/train',
                                                  labels='inferred',label_mode='int',class_names=None,
                                                  color_mode='rgb',batch_size=64,image_size=(299,299),
                                                  shuffle=True,validation_split=0.3,
                                                  interpolation='bilinear',
                                                  subset='training',seed=8,)


valid=tf.keras.utils.image_dataset_from_directory('/content/traffic_sign_classification_dataset/train',
                                                  labels='inferred',label_mode='int',class_names=None,
                                                  color_mode='rgb',batch_size=64,image_size=(299,299),
                                                  shuffle=True,validation_split=0.3,
                                                  interpolation='bilinear',
                                                  subset='validation',seed=8,)

test=tf.keras.utils.image_dataset_from_directory('/content/traffic_sign_classification_dataset/test',
                                                  labels='inferred',label_mode='int',class_names=None,
                                                  color_mode='rgb',batch_size=64,image_size=(299,299),
                                                  shuffle=False,validation_split=0.0,
                                                  interpolation='bilinear',
                                                  subset=None,seed=8,)
print('Total training images:',train.cardinality()*32)
print('Total validation images:',valid.cardinality()*32)
print('Total test images:',test.cardinality()*32)
training_classes:list=train.class_names
valid_classes:list=train.class_names
test_classes:list=train.class_names
assert training_classes==valid_classes==test_classes,'class count in train, valid and test set is not same'
print('Class names:',training_classes)
# Out:
# Found 4438 files belonging to 85 classes.
# Using 3107 files for training.
# Found 4438 files belonging to 85 classes.
# Using 1331 files for validation.
# Found 1288 files belonging to 85 classes.
# Total training images: tf.Tensor(1568, shape=(), dtype=int64)
# Total validation images: tf.Tensor(672, shape=(), dtype=int64)
# Total test images: tf.Tensor(672, shape=(), dtype=int64)
# Class names: ['all_motor_vehicle_prohibited', 'axle_load_limit', 'barrier_ahead', 'bullock_and_handcart_prohibited', 'bullock_prohibited', 'cattle', 'compulsary_ahead', 'compulsary_ahead_or_turn_left', 'compulsary_ahead_or_turn_right', 'compulsary_cycle_track', 'compulsary_keep_left', 'compulsary_keep_right', 'compulsary_minimum_speed', 'compulsary_sound_horn', 'compulsary_turn_left', 'compulsary_turn_left_ahead', 'compulsary_turn_right', 'compulsary_turn_right_ahead', 'cross_road', 'cycle_crossing', 'cycle_prohibited', 'dangerous_dip', 'direction', 'falling_rocks', 'ferry', 'gap_in_median', 'give_way', 'guarded_level_crossing', 'handcart_prohibited', 'height_limit', 'horn_prohibited', 'hump_or_rough_road', 'left_hair_pin_bend', 'left_hand_curve', 'left_reverse_bend', 'left_turn_prohibited', 'length_limit', 'load_limit', 'loose_gravel', 'men_at_work', 'narrow_bridge', 'narrow_road_ahead', 'no_entry', 'no_parking', 'no_stopping_or_standing', 'overtaking_prohibited', 'pass_either_side', 'pedestrian_crossing', 'pedestrian_prohibited', 'priority_for_oncoming_vehicles', 'quay_side_or_river_bank', 'restriction_ends', 'right_hair_pin_bend', 'right_hand_curve', 'right_reverse_bend', 'right_turn_prohibited', 'road_widens_ahead', 'roundabout', 'school_ahead', 'side_road_left', 'side_road_right', 'slippery_road', 'speed_limit_15', 'speed_limit_20', 'speed_limit_30', 'speed_limit_40', 'speed_limit_5', 'speed_limit_50', 'speed_limit_60', 'speed_limit_70', 'speed_limit_80', 'staggered_intersection', 'steep_ascent', 'steep_descent', 'stop', 'straight_prohibited', 't_intersection', 'tonga_prohibited', 'traffic_signal', 'truck_prohibited', 'turn_right', 'u_turn_prohibited', 'unguarded_level_crossing', 'width_limit', 'y_intersection']

# %%
#make plot data
for images,labels in train.take(1):break
images_to_plot:int=9
plt.figure(figsize=(15,15))
for index in range(9):
  plt.subplot(3,3,index+1)
  plt.imshow(images[index].numpy().astype('uint8'))
  plt.axis('off')
  plt.title(training_classes[labels[index].numpy()])
plt.tight_layout()
plt.show()

# %%
# laod base model - Xception
base_model=tf.keras.applications.Xception(include_top=False,weights="imagenet",input_shape=(299,299,3))
#base_model.summary(line_length=120,positions=None,print_fn=None,expand_nested=True,show_trainable=False,layer_range=None)# print base model summary
base_model.trainable=False                                                      # make freeze base
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 1s 0us/step

# %%
inputs=tf.keras.layers.Input(shape=(299,299,3),batch_size=None,name='model_inputs')# add input layer
model_x=tf.keras.layers.Rescaling(2/255,offset=1.0,name='rescaler')(inputs)     # rescale inputs
model_x=base_model(model_x)                                                     # feed inputs to base model
model_x=tf.keras.layers.Flatten(name='flatten')(model_x)                         # make flatten outputs
model_x=tf.keras.layers.Dense(1024,activation='relu')(model_x)                  # apply dense layer
outputs=tf.keras.layers.Dense(len(training_classes),activation='softmax')(model_x)# output layer
model=tf.keras.Model(inputs=[inputs],outputs=[outputs],name='Xception')         # build model
model.summary(line_length=120,positions=None,print_fn=None,expand_nested=True,show_trainable=True,layer_range=None)# print model summary
# Out:
# Model: "Xception"
# ___________________________________________________________________________________________________________________________________
#  Layer (type)                                         Output Shape                                    Param #           Trainable
# ===================================================================================================================================
#  model_inputs (InputLayer)                            [(None, 299, 299, 3)]                           0                 Y
#
#  rescaler (Rescaling)                                 (None, 299, 299, 3)                             0                 Y
#
#  xception (Functional)                                (None, 10, 10, 2048)                            20861480          N
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_1 (InputLayer)                               [(None, 299, 299, 3)]                           0                 N          |
# |                                                                                                                                 |
# | block1_conv1 (Conv2D)                              (None, 149, 149, 32)                            864               N          |
# |                                                                                                                                 |
# | block1_conv1_bn (BatchNormalization)               (None, 149, 149, 32)                            128               N          |
# |                                                                                                                                 |
# | block1_conv1_act (Activation)                      (None, 149, 149, 32)                            0                 N          |
# |                                                                                                                                 |
# | block1_conv2 (Conv2D)                              (None, 147, 147, 64)                            18432             N          |
# |                                                                                                                                 |
# | block1_conv2_bn (BatchNormalization)               (None, 147, 147, 64)                            256               N          |
# |                                                                                                                                 |
# | block1_conv2_act (Activation)                      (None, 147, 147, 64)                            0                 N          |
# |                                                                                                                                 |
# | block2_sepconv1 (SeparableConv2D)                  (None, 147, 147, 128)                           8768              N          |
# |                                                                                                                                 |
# | block2_sepconv1_bn (BatchNormalization)            (None, 147, 147, 128)                           512               N          |
# |                                                                                                                                 |
# | block2_sepconv2_act (Activation)                   (None, 147, 147, 128)                           0                 N          |
# |                                                                                                                                 |
# | block2_sepconv2 (SeparableConv2D)                  (None, 147, 147, 128)                           17536             N          |
# |                                                                                                                                 |
# | block2_sepconv2_bn (BatchNormalization)            (None, 147, 147, 128)                           512               N          |
# |                                                                                                                                 |
# | conv2d (Conv2D)                                    (None, 74, 74, 128)                             8192              N          |
# |                                                                                                                                 |
# | block2_pool (MaxPooling2D)                         (None, 74, 74, 128)                             0                 N          |
# |                                                                                                                                 |
# | batch_normalization (BatchNormalization)           (None, 74, 74, 128)                             512               N          |
# |                                                                                                                                 |
# | add (Add)                                          (None, 74, 74, 128)                             0                 N          |
# |                                                                                                                                 |
# | block3_sepconv1_act (Activation)                   (None, 74, 74, 128)                             0                 N          |
# |                                                                                                                                 |
# | block3_sepconv1 (SeparableConv2D)                  (None, 74, 74, 256)                             33920             N          |
# |                                                                                                                                 |
# | block3_sepconv1_bn (BatchNormalization)            (None, 74, 74, 256)                             1024              N          |
# |                                                                                                                                 |
# | block3_sepconv2_act (Activation)                   (None, 74, 74, 256)                             0                 N          |
# |                                                                                                                                 |
# | block3_sepconv2 (SeparableConv2D)                  (None, 74, 74, 256)                             67840             N          |
# |                                                                                                                                 |
# | block3_sepconv2_bn (BatchNormalization)            (None, 74, 74, 256)                             1024              N          |
# |                                                                                                                                 |
# | conv2d_1 (Conv2D)                                  (None, 37, 37, 256)                             32768             N          |
# |                                                                                                                                 |
# | block3_pool (MaxPooling2D)                         (None, 37, 37, 256)                             0                 N          |
# |                                                                                                                                 |
# | batch_normalization_1 (BatchNormalization)         (None, 37, 37, 256)                             1024              N          |
# |                                                                                                                                 |
# | add_1 (Add)                                        (None, 37, 37, 256)                             0                 N          |
# |                                                                                                                                 |
# | block4_sepconv1_act (Activation)                   (None, 37, 37, 256)                             0                 N          |
# |                                                                                                                                 |
# | block4_sepconv1 (SeparableConv2D)                  (None, 37, 37, 728)                             188672            N          |
# |                                                                                                                                 |
# | block4_sepconv1_bn (BatchNormalization)            (None, 37, 37, 728)                             2912              N          |
# |                                                                                                                                 |
# | block4_sepconv2_act (Activation)                   (None, 37, 37, 728)                             0                 N          |
# |                                                                                                                                 |
# | block4_sepconv2 (SeparableConv2D)                  (None, 37, 37, 728)                             536536            N          |
# |                                                                                                                                 |
# | block4_sepconv2_bn (BatchNormalization)            (None, 37, 37, 728)                             2912              N          |
# |                                                                                                                                 |
# | conv2d_2 (Conv2D)                                  (None, 19, 19, 728)                             186368            N          |
# |                                                                                                                                 |
# | block4_pool (MaxPooling2D)                         (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | batch_normalization_2 (BatchNormalization)         (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | add_2 (Add)                                        (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block5_sepconv1_act (Activation)                   (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block5_sepconv1 (SeparableConv2D)                  (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block5_sepconv1_bn (BatchNormalization)            (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | block5_sepconv2_act (Activation)                   (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block5_sepconv2 (SeparableConv2D)                  (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block5_sepconv2_bn (BatchNormalization)            (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | block5_sepconv3_act (Activation)                   (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block5_sepconv3 (SeparableConv2D)                  (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block5_sepconv3_bn (BatchNormalization)            (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | add_3 (Add)                                        (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block6_sepconv1_act (Activation)                   (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block6_sepconv1 (SeparableConv2D)                  (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block6_sepconv1_bn (BatchNormalization)            (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | block6_sepconv2_act (Activation)                   (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block6_sepconv2 (SeparableConv2D)                  (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block6_sepconv2_bn (BatchNormalization)            (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | block6_sepconv3_act (Activation)                   (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block6_sepconv3 (SeparableConv2D)                  (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block6_sepconv3_bn (BatchNormalization)            (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | add_4 (Add)                                        (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block7_sepconv1_act (Activation)                   (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block7_sepconv1 (SeparableConv2D)                  (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block7_sepconv1_bn (BatchNormalization)            (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | block7_sepconv2_act (Activation)                   (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block7_sepconv2 (SeparableConv2D)                  (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block7_sepconv2_bn (BatchNormalization)            (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | block7_sepconv3_act (Activation)                   (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block7_sepconv3 (SeparableConv2D)                  (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block7_sepconv3_bn (BatchNormalization)            (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | add_5 (Add)                                        (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block8_sepconv1_act (Activation)                   (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block8_sepconv1 (SeparableConv2D)                  (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block8_sepconv1_bn (BatchNormalization)            (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | block8_sepconv2_act (Activation)                   (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block8_sepconv2 (SeparableConv2D)                  (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block8_sepconv2_bn (BatchNormalization)            (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | block8_sepconv3_act (Activation)                   (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block8_sepconv3 (SeparableConv2D)                  (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block8_sepconv3_bn (BatchNormalization)            (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | add_6 (Add)                                        (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block9_sepconv1_act (Activation)                   (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block9_sepconv1 (SeparableConv2D)                  (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block9_sepconv1_bn (BatchNormalization)            (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | block9_sepconv2_act (Activation)                   (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block9_sepconv2 (SeparableConv2D)                  (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block9_sepconv2_bn (BatchNormalization)            (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | block9_sepconv3_act (Activation)                   (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block9_sepconv3 (SeparableConv2D)                  (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block9_sepconv3_bn (BatchNormalization)            (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | add_7 (Add)                                        (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block10_sepconv1_act (Activation)                  (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block10_sepconv1 (SeparableConv2D)                 (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block10_sepconv1_bn (BatchNormalization)           (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | block10_sepconv2_act (Activation)                  (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block10_sepconv2 (SeparableConv2D)                 (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block10_sepconv2_bn (BatchNormalization)           (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | block10_sepconv3_act (Activation)                  (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block10_sepconv3 (SeparableConv2D)                 (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block10_sepconv3_bn (BatchNormalization)           (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | add_8 (Add)                                        (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block11_sepconv1_act (Activation)                  (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block11_sepconv1 (SeparableConv2D)                 (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block11_sepconv1_bn (BatchNormalization)           (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | block11_sepconv2_act (Activation)                  (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block11_sepconv2 (SeparableConv2D)                 (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block11_sepconv2_bn (BatchNormalization)           (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | block11_sepconv3_act (Activation)                  (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block11_sepconv3 (SeparableConv2D)                 (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block11_sepconv3_bn (BatchNormalization)           (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | add_9 (Add)                                        (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block12_sepconv1_act (Activation)                  (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block12_sepconv1 (SeparableConv2D)                 (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block12_sepconv1_bn (BatchNormalization)           (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | block12_sepconv2_act (Activation)                  (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block12_sepconv2 (SeparableConv2D)                 (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block12_sepconv2_bn (BatchNormalization)           (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | block12_sepconv3_act (Activation)                  (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block12_sepconv3 (SeparableConv2D)                 (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block12_sepconv3_bn (BatchNormalization)           (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | add_10 (Add)                                       (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block13_sepconv1_act (Activation)                  (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block13_sepconv1 (SeparableConv2D)                 (None, 19, 19, 728)                             536536            N          |
# |                                                                                                                                 |
# | block13_sepconv1_bn (BatchNormalization)           (None, 19, 19, 728)                             2912              N          |
# |                                                                                                                                 |
# | block13_sepconv2_act (Activation)                  (None, 19, 19, 728)                             0                 N          |
# |                                                                                                                                 |
# | block13_sepconv2 (SeparableConv2D)                 (None, 19, 19, 1024)                            752024            N          |
# |                                                                                                                                 |
# | block13_sepconv2_bn (BatchNormalization)           (None, 19, 19, 1024)                            4096              N          |
# |                                                                                                                                 |
# | conv2d_3 (Conv2D)                                  (None, 10, 10, 1024)                            745472            N          |
# |                                                                                                                                 |
# | block13_pool (MaxPooling2D)                        (None, 10, 10, 1024)                            0                 N          |
# |                                                                                                                                 |
# | batch_normalization_3 (BatchNormalization)         (None, 10, 10, 1024)                            4096              N          |
# |                                                                                                                                 |
# | add_11 (Add)                                       (None, 10, 10, 1024)                            0                 N          |
# |                                                                                                                                 |
# | block14_sepconv1 (SeparableConv2D)                 (None, 10, 10, 1536)                            1582080           N          |
# |                                                                                                                                 |
# | block14_sepconv1_bn (BatchNormalization)           (None, 10, 10, 1536)                            6144              N          |
# |                                                                                                                                 |
# | block14_sepconv1_act (Activation)                  (None, 10, 10, 1536)                            0                 N          |
# |                                                                                                                                 |
# | block14_sepconv2 (SeparableConv2D)                 (None, 10, 10, 2048)                            3159552           N          |
# |                                                                                                                                 |
# | block14_sepconv2_bn (BatchNormalization)           (None, 10, 10, 2048)                            8192              N          |
# |                                                                                                                                 |
# | block14_sepconv2_act (Activation)                  (None, 10, 10, 2048)                            0                 N          |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  flatten (Flatten)                                    (None, 204800)                                  0                 Y
#
#  dense (Dense)                                        (None, 1024)                                    209716224         Y
#
#  dense_1 (Dense)                                      (None, 85)                                      87125             Y
#
# ===================================================================================================================================
# Total params: 230,664,829
# Trainable params: 209,803,349
# Non-trainable params: 20,861,480
# ___________________________________________________________________________________________________________________________________

# %%
# make compile model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=tf.keras.metrics.SparseCategoricalAccuracy())

# %%
# make early stopping
early_stop=tf.keras.callbacks.EarlyStopping(monitor='val_sparse_categorical_accuracy',min_delta=0,patience=10,verbose=1,mode='auto',restore_best_weights=True)

# make train model
history=model.fit(train,batch_size=None,epochs=10_000,verbose=2,callbacks=[early_stop],
                  validation_split=0,validation_data=valid,shuffle=True)
# Out:
# Epoch 1/10000

# %%
# see model history (first five epoches)
pd.DataFrame(history.history).head()

# %%
# see model history (last five epoches)
pd.DataFrame(history.history).tail()

# %%
# make plot training accuracy and validation accuracy
pd.DataFrame(history.history)[['sparse_categorical_accuracy','val_sparse_categorical_accuracy']].plot(marker='.')# make plot
plt.grid(),plt.title('Training Accuracy'),plt.xlabel('epochs'),plt.ylabel('accuracy')# add grid, title and axis labels
plt.show()

# %%
# make plot training losses and validation losses
pd.DataFrame(history.history)[['loss','val_loss']].plot(marker='.')             # make plot
plt.grid(),plt.title('Training Losses'),plt.xlabel('epochs'),plt.ylabel('loss') # add grid, title and axis labels
plt.show()

# %%
# evaluate model
results=model.evaluate(test,batch_size=None,verbose="auto",sample_weight=None,return_dict=True)
print('Testing results:',results)                                               #print results

# %%
# make save model (weights and configuration)
model.save('traffic_sign_classifier',overwrite=True,save_format=None)           # make save

# %%
# !zip -r -qq "traffic_sign_classifier.zip" "traffic_sign_classifier"             # make zip model
# make auto download model weights
from google.colab import files                                                  # load file class
files.download('traffic_sign_classifier.zip')                                   # download model zip file
