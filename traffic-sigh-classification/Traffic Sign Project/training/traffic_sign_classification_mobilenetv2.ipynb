# %%
# !python -m pip install -qq kaggle

# %%
# %%bash
# mkdir ~/.kaggle
# cp kaggle.json ~/.kaggle/
# chmod 600 /root/.kaggle/kaggle.json
# kaggle datasets download sarangdilipjodh/indian-traffic-signs-prediction85-classes
# unzip -qq "/content/indian-traffic-signs-prediction85-classes.zip"
# rm -rf "/content/sample_data"
# Out:
# Downloading indian-traffic-signs-prediction85-classes.zip to /content
# 100%|██████████| 1.13G/1.13G [00:16<00:00, 73.3MB/s]

# %%
import os                        # Module for interacting with the operating system
import string                    # Module with utility functions for working with strings
import numpy as np               # Numerical computing library
import pandas as pd              # Library for data manipulation and analysis
import seaborn as sns            # Data visualization library built on top of matplotlib
import tensorflow as tf         # Deep learning framework
from matplotlib import pyplot as plt  # Plotting library
from PIL import Image            # Library for working with images
import re                        # Module for working with regular expressions

# %%
# Traning classes
training_classes=os.listdir('/content/traffic_sign_classification_dataset/train')
print('Total classes:',len(training_classes))
print('Class names:',training_classes)
#clean class names
training_classes_clean=[re.sub('[^A-Za-z0-9 ]',' ',class_)for class_ in training_classes]
training_classes_clean=[re.sub('[ ]+','_',class_).casefold() for class_ in training_classes_clean]
print('Cleaned class names:',training_classes_clean)
#rename classes name with clean class names
for old_name,new_name in zip(training_classes,training_classes_clean):
  os.rename(os.path.join('/content/traffic_sign_classification_dataset/train',old_name),
            os.path.join('/content/traffic_sign_classification_dataset/train',new_name))
# Out:
# Total classes: 85
# Class names: ['SPEED_LIMIT_70', 'LOOSE_GRAVEL', 'SPEED_LIMIT_20', 'RESTRICTION_ENDS', 'ALL_MOTOR_VEHICLE_PROHIBITED', 'STOP', 'SPEED_LIMIT_50', 'SPEED_LIMIT_80', 'RIGHT_TURN_PROHIBITED', 'STRAIGHT_PROHIBITED', 'HUMP_OR_ROUGH_ROAD', 'COMPULSARY_TURN_RIGHT_AHEAD', 'PEDESTRIAN_PROHIBITED', 'NO_ENTRY', 'TRAFFIC_SIGNAL', 'TURN_RIGHT', 'CATTLE', 'COMPULSARY_MINIMUM_SPEED', 'STEEP_ASCENT', 'COMPULSARY_KEEP_LEFT', 'SPEED_LIMIT_60', 'AXLE_LOAD_LIMIT', 'HEIGHT_LIMIT', 'LEFT_HAIR_PIN_BEND', 'SPEED_LIMIT_30', 'PRIORITY_FOR_ONCOMING_VEHICLES', 'STEEP_DESCENT', 'SPEED_LIMIT_5', 'COMPULSARY_AHEAD_OR_TURN_LEFT', 'NO_STOPPING_OR_STANDING', 'COMPULSARY_KEEP_RIGHT', 'ROAD_WIDENS_AHEAD', 'COMPULSARY_CYCLE_TRACK', 'CYCLE_PROHIBITED', 'NARROW_BRIDGE', 'BULLOCK_AND_HANDCART_PROHIBITED', 'COMPULSARY_TURN_LEFT', 'FERRY', 'GUARDED_LEVEL_CROSSING', 'RIGHT_HAIR_PIN_BEND', 'LENGTH_LIMIT', 'BARRIER_AHEAD', 'PASS_EITHER_SIDE', 'TRUCK_PROHIBITED', 'COMPULSARY_AHEAD', 'COMPULSARY_AHEAD_OR_TURN_RIGHT', 'RIGHT_HAND_CURVE', 'NARROW_ROAD_AHEAD', 'T_INTERSECTION', 'NO_PARKING', 'HANDCART_PROHIBITED', 'WIDTH_LIMIT', 'UNGUARDED_LEVEL_CROSSING', 'TONGA_PROHIBITED', 'SIDE_ROAD_LEFT', 'SLIPPERY_ROAD', 'COMPULSARY_SOUND_HORN', 'DANGEROUS_DIP', 'ROUNDABOUT', 'SPEED_LIMIT_15', 'U_TURN_PROHIBITED', 'LEFT_TURN_PROHIBITED', 'QUAY_SIDE_OR_RIVER_BANK', 'HORN_PROHIBITED', 'OVERTAKING_PROHIBITED', 'LEFT_REVERSE_BEND', 'RIGHT_REVERSE_BEND', 'SIDE_ROAD_RIGHT', 'CYCLE_CROSSING', 'DIRECTION', 'SCHOOL_AHEAD', 'FALLING_ROCKS', 'Y_INTERSECTION', 'MEN_AT_WORK', 'GIVE_WAY', 'PEDESTRIAN_CROSSING', 'GAP_IN_MEDIAN', 'COMPULSARY_TURN_LEFT_AHEAD', 'BULLOCK_PROHIBITED', 'STAGGERED_INTERSECTION', 'SPEED_LIMIT_40', 'CROSS_ROAD', 'LEFT_HAND_CURVE', 'COMPULSARY_TURN_RIGHT', 'LOAD_LIMIT']
# Cleaned class names: ['speed_limit_70', 'loose_gravel', 'speed_limit_20', 'restriction_ends', 'all_motor_vehicle_prohibited', 'stop', 'speed_limit_50', 'speed_limit_80', 'right_turn_prohibited', 'straight_prohibited', 'hump_or_rough_road', 'compulsary_turn_right_ahead', 'pedestrian_prohibited', 'no_entry', 'traffic_signal', 'turn_right', 'cattle', 'compulsary_minimum_speed', 'steep_ascent', 'compulsary_keep_left', 'speed_limit_60', 'axle_load_limit', 'height_limit', 'left_hair_pin_bend', 'speed_limit_30', 'priority_for_oncoming_vehicles', 'steep_descent', 'speed_limit_5', 'compulsary_ahead_or_turn_left', 'no_stopping_or_standing', 'compulsary_keep_right', 'road_widens_ahead', 'compulsary_cycle_track', 'cycle_prohibited', 'narrow_bridge', 'bullock_and_handcart_prohibited', 'compulsary_turn_left', 'ferry', 'guarded_level_crossing', 'right_hair_pin_bend', 'length_limit', 'barrier_ahead', 'pass_either_side', 'truck_prohibited', 'compulsary_ahead', 'compulsary_ahead_or_turn_right', 'right_hand_curve', 'narrow_road_ahead', 't_intersection', 'no_parking', 'handcart_prohibited', 'width_limit', 'unguarded_level_crossing', 'tonga_prohibited', 'side_road_left', 'slippery_road', 'compulsary_sound_horn', 'dangerous_dip', 'roundabout', 'speed_limit_15', 'u_turn_prohibited', 'left_turn_prohibited', 'quay_side_or_river_bank', 'horn_prohibited', 'overtaking_prohibited', 'left_reverse_bend', 'right_reverse_bend', 'side_road_right', 'cycle_crossing', 'direction', 'school_ahead', 'falling_rocks', 'y_intersection', 'men_at_work', 'give_way', 'pedestrian_crossing', 'gap_in_median', 'compulsary_turn_left_ahead', 'bullock_prohibited', 'staggered_intersection', 'speed_limit_40', 'cross_road', 'left_hand_curve', 'compulsary_turn_right', 'load_limit']

# %%
# Testing classes
testing_classes=os.listdir('/content/traffic_sign_classification_dataset/test')
print('Total classes:',len(testing_classes))
print('Class names:',testing_classes)
#clean class names
testing_classes_clean=[re.sub('[^A-Za-z0-9 ]',' ',class_)for class_ in testing_classes]
testing_classes_clean=[re.sub('[ ]+','_',class_).casefold() for class_ in testing_classes_clean]
print('Cleaned class names:',testing_classes_clean)
#rename classes name with clean class names
for old_name,new_name in zip(testing_classes,testing_classes_clean):
  os.rename(os.path.join('/content/traffic_sign_classification_dataset/test',old_name),
            os.path.join('/content/traffic_sign_classification_dataset/test',new_name))
# Out:
# Total classes: 85
# Class names: ['SPEED_LIMIT_70', 'LOOSE_GRAVEL', 'SPEED_LIMIT_20', 'RESTRICTION_ENDS', 'ALL_MOTOR_VEHICLE_PROHIBITED', 'STOP', 'SPEED_LIMIT_50', 'SPEED_LIMIT_80', 'RIGHT_TURN_PROHIBITED', 'STRAIGHT_PROHIBITED', 'HUMP_OR_ROUGH_ROAD', 'COMPULSARY_TURN_RIGHT_AHEAD', 'PEDESTRIAN_PROHIBITED', 'NO_ENTRY', 'TRAFFIC_SIGNAL', 'TURN_RIGHT', 'CATTLE', 'COMPULSARY_MINIMUM_SPEED', 'STEEP_ASCENT', 'COMPULSARY_KEEP_LEFT', 'SPEED_LIMIT_60', 'AXLE_LOAD_LIMIT', 'HEIGHT_LIMIT', 'LEFT_HAIR_PIN_BEND', 'SPEED_LIMIT_30', 'PRIORITY_FOR_ONCOMING_VEHICLES', 'STEEP_DESCENT', 'SPEED_LIMIT_5', 'COMPULSARY_AHEAD_OR_TURN_LEFT', 'NO_STOPPING_OR_STANDING', 'COMPULSARY_KEEP_RIGHT', 'ROAD_WIDENS_AHEAD', 'COMPULSARY_CYCLE_TRACK', 'CYCLE_PROHIBITED', 'NARROW_BRIDGE', 'BULLOCK_AND_HANDCART_PROHIBITED', 'COMPULSARY_TURN_LEFT', 'FERRY', 'GUARDED_LEVEL_CROSSING', 'RIGHT_HAIR_PIN_BEND', 'LENGTH_LIMIT', 'BARRIER_AHEAD', 'PASS_EITHER_SIDE', 'TRUCK_PROHIBITED', 'COMPULSARY_AHEAD', 'COMPULSARY_AHEAD_OR_TURN_RIGHT', 'RIGHT_HAND_CURVE', 'NARROW_ROAD_AHEAD', 'T_INTERSECTION', 'NO_PARKING', 'HANDCART_PROHIBITED', 'WIDTH_LIMIT', 'UNGUARDED_LEVEL_CROSSING', 'TONGA_PROHIBITED', 'SIDE_ROAD_LEFT', 'SLIPPERY_ROAD', 'COMPULSARY_SOUND_HORN', 'DANGEROUS_DIP', 'ROUNDABOUT', 'SPEED_LIMIT_15', 'U_TURN_PROHIBITED', 'LEFT_TURN_PROHIBITED', 'QUAY_SIDE_OR_RIVER_BANK', 'HORN_PROHIBITED', 'OVERTAKING_PROHIBITED', 'LEFT_REVERSE_BEND', 'RIGHT_REVERSE_BEND', 'SIDE_ROAD_RIGHT', 'CYCLE_CROSSING', 'DIRECTION', 'SCHOOL_AHEAD', 'FALLING_ROCKS', 'Y_INTERSECTION', 'MEN_AT_WORK', 'GIVE_WAY', 'PEDESTRIAN_CROSSING', 'GAP_IN_MEDIAN', 'COMPULSARY_TURN_LEFT_AHEAD', 'BULLOCK_PROHIBITED', 'STAGGERED_INTERSECTION', 'SPEED_LIMIT_40', 'CROSS_ROAD', 'LEFT_HAND_CURVE', 'COMPULSARY_TURN_RIGHT', 'LOAD_LIMIT']
# Cleaned class names: ['speed_limit_70', 'loose_gravel', 'speed_limit_20', 'restriction_ends', 'all_motor_vehicle_prohibited', 'stop', 'speed_limit_50', 'speed_limit_80', 'right_turn_prohibited', 'straight_prohibited', 'hump_or_rough_road', 'compulsary_turn_right_ahead', 'pedestrian_prohibited', 'no_entry', 'traffic_signal', 'turn_right', 'cattle', 'compulsary_minimum_speed', 'steep_ascent', 'compulsary_keep_left', 'speed_limit_60', 'axle_load_limit', 'height_limit', 'left_hair_pin_bend', 'speed_limit_30', 'priority_for_oncoming_vehicles', 'steep_descent', 'speed_limit_5', 'compulsary_ahead_or_turn_left', 'no_stopping_or_standing', 'compulsary_keep_right', 'road_widens_ahead', 'compulsary_cycle_track', 'cycle_prohibited', 'narrow_bridge', 'bullock_and_handcart_prohibited', 'compulsary_turn_left', 'ferry', 'guarded_level_crossing', 'right_hair_pin_bend', 'length_limit', 'barrier_ahead', 'pass_either_side', 'truck_prohibited', 'compulsary_ahead', 'compulsary_ahead_or_turn_right', 'right_hand_curve', 'narrow_road_ahead', 't_intersection', 'no_parking', 'handcart_prohibited', 'width_limit', 'unguarded_level_crossing', 'tonga_prohibited', 'side_road_left', 'slippery_road', 'compulsary_sound_horn', 'dangerous_dip', 'roundabout', 'speed_limit_15', 'u_turn_prohibited', 'left_turn_prohibited', 'quay_side_or_river_bank', 'horn_prohibited', 'overtaking_prohibited', 'left_reverse_bend', 'right_reverse_bend', 'side_road_right', 'cycle_crossing', 'direction', 'school_ahead', 'falling_rocks', 'y_intersection', 'men_at_work', 'give_way', 'pedestrian_crossing', 'gap_in_median', 'compulsary_turn_left_ahead', 'bullock_prohibited', 'staggered_intersection', 'speed_limit_40', 'cross_road', 'left_hand_curve', 'compulsary_turn_right', 'load_limit']

# %%
from tensorflow.python.ops.gen_batch_ops import batch
#load dataset - train,test and valid
train=tf.keras.utils.image_dataset_from_directory('/content/traffic_sign_classification_dataset/train',
                                                  labels='inferred',label_mode='int',class_names=None,
                                                  color_mode='rgb',batch_size=64,image_size=(160,160),
                                                  shuffle=True,validation_split=0.3,
                                                  interpolation='bilinear',
                                                  subset='training',seed=8,)


valid=tf.keras.utils.image_dataset_from_directory('/content/traffic_sign_classification_dataset/train',
                                                  labels='inferred',label_mode='int',class_names=None,
                                                  color_mode='rgb',batch_size=64,image_size=(160,160),
                                                  shuffle=True,validation_split=0.3,
                                                  interpolation='bilinear',
                                                  subset='validation',seed=8,)

test=tf.keras.utils.image_dataset_from_directory('/content/traffic_sign_classification_dataset/test',
                                                  labels='inferred',label_mode='int',class_names=None,
                                                  color_mode='rgb',batch_size=64,image_size=(160,160),
                                                  shuffle=False,validation_split=0.0,
                                                  interpolation='bilinear',
                                                  subset=None,seed=8,)
print('Total training images:',train.cardinality()*32)
print('Total validation images:',valid.cardinality()*32)
print('Total test images:',test.cardinality()*32)
training_classes:list=train.class_names
valid_classes:list=train.class_names
test_classes:list=train.class_names
assert training_classes==valid_classes==test_classes,'class count in train, valid and test set is not same'
print('Class names:',training_classes)
# Out:
# Found 4438 files belonging to 85 classes.
# Using 3107 files for training.
# Found 4438 files belonging to 85 classes.
# Using 1331 files for validation.
# Found 1288 files belonging to 85 classes.
# Total training images: tf.Tensor(1568, shape=(), dtype=int64)
# Total validation images: tf.Tensor(672, shape=(), dtype=int64)
# Total test images: tf.Tensor(672, shape=(), dtype=int64)
# Class names: ['all_motor_vehicle_prohibited', 'axle_load_limit', 'barrier_ahead', 'bullock_and_handcart_prohibited', 'bullock_prohibited', 'cattle', 'compulsary_ahead', 'compulsary_ahead_or_turn_left', 'compulsary_ahead_or_turn_right', 'compulsary_cycle_track', 'compulsary_keep_left', 'compulsary_keep_right', 'compulsary_minimum_speed', 'compulsary_sound_horn', 'compulsary_turn_left', 'compulsary_turn_left_ahead', 'compulsary_turn_right', 'compulsary_turn_right_ahead', 'cross_road', 'cycle_crossing', 'cycle_prohibited', 'dangerous_dip', 'direction', 'falling_rocks', 'ferry', 'gap_in_median', 'give_way', 'guarded_level_crossing', 'handcart_prohibited', 'height_limit', 'horn_prohibited', 'hump_or_rough_road', 'left_hair_pin_bend', 'left_hand_curve', 'left_reverse_bend', 'left_turn_prohibited', 'length_limit', 'load_limit', 'loose_gravel', 'men_at_work', 'narrow_bridge', 'narrow_road_ahead', 'no_entry', 'no_parking', 'no_stopping_or_standing', 'overtaking_prohibited', 'pass_either_side', 'pedestrian_crossing', 'pedestrian_prohibited', 'priority_for_oncoming_vehicles', 'quay_side_or_river_bank', 'restriction_ends', 'right_hair_pin_bend', 'right_hand_curve', 'right_reverse_bend', 'right_turn_prohibited', 'road_widens_ahead', 'roundabout', 'school_ahead', 'side_road_left', 'side_road_right', 'slippery_road', 'speed_limit_15', 'speed_limit_20', 'speed_limit_30', 'speed_limit_40', 'speed_limit_5', 'speed_limit_50', 'speed_limit_60', 'speed_limit_70', 'speed_limit_80', 'staggered_intersection', 'steep_ascent', 'steep_descent', 'stop', 'straight_prohibited', 't_intersection', 'tonga_prohibited', 'traffic_signal', 'truck_prohibited', 'turn_right', 'u_turn_prohibited', 'unguarded_level_crossing', 'width_limit', 'y_intersection']

# %%
#make plot data
for images,labels in train.take(1):break
images_to_plot:int=9
plt.figure(figsize=(15,15))
for index in range(9):
  plt.subplot(3,3,index+1)
  plt.imshow(images[index].numpy().astype('uint8'))
  plt.axis('off')
  plt.title(training_classes[labels[index].numpy()])
plt.tight_layout()
plt.show()

# %%
# laod base model - MobileNetV2
base_model=tf.keras.applications.MobileNetV2(include_top=False,weights="imagenet",input_shape=(160,160,3))
#base_model.summary(line_length=120,positions=None,print_fn=None,expand_nested=True,show_trainable=False,layer_range=None)# print base model summary
base_model.trainable=False                                                      # make freeze base
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_160_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %%
inputs=tf.keras.layers.Input(shape=(160,160,3),batch_size=None,name='model_inputs')# add input layer
model_x=tf.keras.layers.Rescaling(1/255,offset=1.0,name='rescaler')(inputs)     # rescale inputs
model_x=base_model(model_x)                                                     # feed inputs to base model
model_x=tf.keras.layers.Flatten(name='flatten')(model_x)                         # make flatten outputs
model_x=tf.keras.layers.Dense(1024,activation='relu')(model_x)                  # apply dense layer
outputs=tf.keras.layers.Dense(len(training_classes),activation='softmax')(model_x)# output layer
model=tf.keras.Model(inputs=[inputs],outputs=[outputs],name='Xception')         # build model
model.summary(line_length=120,positions=None,print_fn=None,expand_nested=True,show_trainable=True,layer_range=None)# print model summary
# Out:
# Model: "Xception"
# ___________________________________________________________________________________________________________________________________
#  Layer (type)                                         Output Shape                                    Param #           Trainable
# ===================================================================================================================================
#  model_inputs (InputLayer)                            [(None, 160, 160, 3)]                           0                 Y
#
#  rescaler (Rescaling)                                 (None, 160, 160, 3)                             0                 Y
#
#  mobilenetv2_1.00_160 (Functional)                    (None, 5, 5, 1280)                              2257984           N
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_1 (InputLayer)                               [(None, 160, 160, 3)]                           0                 N          |
# |                                                                                                                                 |
# | Conv1 (Conv2D)                                     (None, 80, 80, 32)                              864               N          |
# |                                                                                                                                 |
# | bn_Conv1 (BatchNormalization)                      (None, 80, 80, 32)                              128               N          |
# |                                                                                                                                 |
# | Conv1_relu (ReLU)                                  (None, 80, 80, 32)                              0                 N          |
# |                                                                                                                                 |
# | expanded_conv_depthwise (DepthwiseConv2D)          (None, 80, 80, 32)                              288               N          |
# |                                                                                                                                 |
# | expanded_conv_depthwise_BN (BatchNormalization)    (None, 80, 80, 32)                              128               N          |
# |                                                                                                                                 |
# | expanded_conv_depthwise_relu (ReLU)                (None, 80, 80, 32)                              0                 N          |
# |                                                                                                                                 |
# | expanded_conv_project (Conv2D)                     (None, 80, 80, 16)                              512               N          |
# |                                                                                                                                 |
# | expanded_conv_project_BN (BatchNormalization)      (None, 80, 80, 16)                              64                N          |
# |                                                                                                                                 |
# | block_1_expand (Conv2D)                            (None, 80, 80, 96)                              1536              N          |
# |                                                                                                                                 |
# | block_1_expand_BN (BatchNormalization)             (None, 80, 80, 96)                              384               N          |
# |                                                                                                                                 |
# | block_1_expand_relu (ReLU)                         (None, 80, 80, 96)                              0                 N          |
# |                                                                                                                                 |
# | block_1_pad (ZeroPadding2D)                        (None, 81, 81, 96)                              0                 N          |
# |                                                                                                                                 |
# | block_1_depthwise (DepthwiseConv2D)                (None, 40, 40, 96)                              864               N          |
# |                                                                                                                                 |
# | block_1_depthwise_BN (BatchNormalization)          (None, 40, 40, 96)                              384               N          |
# |                                                                                                                                 |
# | block_1_depthwise_relu (ReLU)                      (None, 40, 40, 96)                              0                 N          |
# |                                                                                                                                 |
# | block_1_project (Conv2D)                           (None, 40, 40, 24)                              2304              N          |
# |                                                                                                                                 |
# | block_1_project_BN (BatchNormalization)            (None, 40, 40, 24)                              96                N          |
# |                                                                                                                                 |
# | block_2_expand (Conv2D)                            (None, 40, 40, 144)                             3456              N          |
# |                                                                                                                                 |
# | block_2_expand_BN (BatchNormalization)             (None, 40, 40, 144)                             576               N          |
# |                                                                                                                                 |
# | block_2_expand_relu (ReLU)                         (None, 40, 40, 144)                             0                 N          |
# |                                                                                                                                 |
# | block_2_depthwise (DepthwiseConv2D)                (None, 40, 40, 144)                             1296              N          |
# |                                                                                                                                 |
# | block_2_depthwise_BN (BatchNormalization)          (None, 40, 40, 144)                             576               N          |
# |                                                                                                                                 |
# | block_2_depthwise_relu (ReLU)                      (None, 40, 40, 144)                             0                 N          |
# |                                                                                                                                 |
# | block_2_project (Conv2D)                           (None, 40, 40, 24)                              3456              N          |
# |                                                                                                                                 |
# | block_2_project_BN (BatchNormalization)            (None, 40, 40, 24)                              96                N          |
# |                                                                                                                                 |
# | block_2_add (Add)                                  (None, 40, 40, 24)                              0                 N          |
# |                                                                                                                                 |
# | block_3_expand (Conv2D)                            (None, 40, 40, 144)                             3456              N          |
# |                                                                                                                                 |
# | block_3_expand_BN (BatchNormalization)             (None, 40, 40, 144)                             576               N          |
# |                                                                                                                                 |
# | block_3_expand_relu (ReLU)                         (None, 40, 40, 144)                             0                 N          |
# |                                                                                                                                 |
# | block_3_pad (ZeroPadding2D)                        (None, 41, 41, 144)                             0                 N          |
# |                                                                                                                                 |
# | block_3_depthwise (DepthwiseConv2D)                (None, 20, 20, 144)                             1296              N          |
# |                                                                                                                                 |
# | block_3_depthwise_BN (BatchNormalization)          (None, 20, 20, 144)                             576               N          |
# |                                                                                                                                 |
# | block_3_depthwise_relu (ReLU)                      (None, 20, 20, 144)                             0                 N          |
# |                                                                                                                                 |
# | block_3_project (Conv2D)                           (None, 20, 20, 32)                              4608              N          |
# |                                                                                                                                 |
# | block_3_project_BN (BatchNormalization)            (None, 20, 20, 32)                              128               N          |
# |                                                                                                                                 |
# | block_4_expand (Conv2D)                            (None, 20, 20, 192)                             6144              N          |
# |                                                                                                                                 |
# | block_4_expand_BN (BatchNormalization)             (None, 20, 20, 192)                             768               N          |
# |                                                                                                                                 |
# | block_4_expand_relu (ReLU)                         (None, 20, 20, 192)                             0                 N          |
# |                                                                                                                                 |
# | block_4_depthwise (DepthwiseConv2D)                (None, 20, 20, 192)                             1728              N          |
# |                                                                                                                                 |
# | block_4_depthwise_BN (BatchNormalization)          (None, 20, 20, 192)                             768               N          |
# |                                                                                                                                 |
# | block_4_depthwise_relu (ReLU)                      (None, 20, 20, 192)                             0                 N          |
# |                                                                                                                                 |
# | block_4_project (Conv2D)                           (None, 20, 20, 32)                              6144              N          |
# |                                                                                                                                 |
# | block_4_project_BN (BatchNormalization)            (None, 20, 20, 32)                              128               N          |
# |                                                                                                                                 |
# | block_4_add (Add)                                  (None, 20, 20, 32)                              0                 N          |
# |                                                                                                                                 |
# | block_5_expand (Conv2D)                            (None, 20, 20, 192)                             6144              N          |
# |                                                                                                                                 |
# | block_5_expand_BN (BatchNormalization)             (None, 20, 20, 192)                             768               N          |
# |                                                                                                                                 |
# | block_5_expand_relu (ReLU)                         (None, 20, 20, 192)                             0                 N          |
# |                                                                                                                                 |
# | block_5_depthwise (DepthwiseConv2D)                (None, 20, 20, 192)                             1728              N          |
# |                                                                                                                                 |
# | block_5_depthwise_BN (BatchNormalization)          (None, 20, 20, 192)                             768               N          |
# |                                                                                                                                 |
# | block_5_depthwise_relu (ReLU)                      (None, 20, 20, 192)                             0                 N          |
# |                                                                                                                                 |
# | block_5_project (Conv2D)                           (None, 20, 20, 32)                              6144              N          |
# |                                                                                                                                 |
# | block_5_project_BN (BatchNormalization)            (None, 20, 20, 32)                              128               N          |
# |                                                                                                                                 |
# | block_5_add (Add)                                  (None, 20, 20, 32)                              0                 N          |
# |                                                                                                                                 |
# | block_6_expand (Conv2D)                            (None, 20, 20, 192)                             6144              N          |
# |                                                                                                                                 |
# | block_6_expand_BN (BatchNormalization)             (None, 20, 20, 192)                             768               N          |
# |                                                                                                                                 |
# | block_6_expand_relu (ReLU)                         (None, 20, 20, 192)                             0                 N          |
# |                                                                                                                                 |
# | block_6_pad (ZeroPadding2D)                        (None, 21, 21, 192)                             0                 N          |
# |                                                                                                                                 |
# | block_6_depthwise (DepthwiseConv2D)                (None, 10, 10, 192)                             1728              N          |
# |                                                                                                                                 |
# | block_6_depthwise_BN (BatchNormalization)          (None, 10, 10, 192)                             768               N          |
# |                                                                                                                                 |
# | block_6_depthwise_relu (ReLU)                      (None, 10, 10, 192)                             0                 N          |
# |                                                                                                                                 |
# | block_6_project (Conv2D)                           (None, 10, 10, 64)                              12288             N          |
# |                                                                                                                                 |
# | block_6_project_BN (BatchNormalization)            (None, 10, 10, 64)                              256               N          |
# |                                                                                                                                 |
# | block_7_expand (Conv2D)                            (None, 10, 10, 384)                             24576             N          |
# |                                                                                                                                 |
# | block_7_expand_BN (BatchNormalization)             (None, 10, 10, 384)                             1536              N          |
# |                                                                                                                                 |
# | block_7_expand_relu (ReLU)                         (None, 10, 10, 384)                             0                 N          |
# |                                                                                                                                 |
# | block_7_depthwise (DepthwiseConv2D)                (None, 10, 10, 384)                             3456              N          |
# |                                                                                                                                 |
# | block_7_depthwise_BN (BatchNormalization)          (None, 10, 10, 384)                             1536              N          |
# |                                                                                                                                 |
# | block_7_depthwise_relu (ReLU)                      (None, 10, 10, 384)                             0                 N          |
# |                                                                                                                                 |
# | block_7_project (Conv2D)                           (None, 10, 10, 64)                              24576             N          |
# |                                                                                                                                 |
# | block_7_project_BN (BatchNormalization)            (None, 10, 10, 64)                              256               N          |
# |                                                                                                                                 |
# | block_7_add (Add)                                  (None, 10, 10, 64)                              0                 N          |
# |                                                                                                                                 |
# | block_8_expand (Conv2D)                            (None, 10, 10, 384)                             24576             N          |
# |                                                                                                                                 |
# | block_8_expand_BN (BatchNormalization)             (None, 10, 10, 384)                             1536              N          |
# |                                                                                                                                 |
# | block_8_expand_relu (ReLU)                         (None, 10, 10, 384)                             0                 N          |
# |                                                                                                                                 |
# | block_8_depthwise (DepthwiseConv2D)                (None, 10, 10, 384)                             3456              N          |
# |                                                                                                                                 |
# | block_8_depthwise_BN (BatchNormalization)          (None, 10, 10, 384)                             1536              N          |
# |                                                                                                                                 |
# | block_8_depthwise_relu (ReLU)                      (None, 10, 10, 384)                             0                 N          |
# |                                                                                                                                 |
# | block_8_project (Conv2D)                           (None, 10, 10, 64)                              24576             N          |
# |                                                                                                                                 |
# | block_8_project_BN (BatchNormalization)            (None, 10, 10, 64)                              256               N          |
# |                                                                                                                                 |
# | block_8_add (Add)                                  (None, 10, 10, 64)                              0                 N          |
# |                                                                                                                                 |
# | block_9_expand (Conv2D)                            (None, 10, 10, 384)                             24576             N          |
# |                                                                                                                                 |
# | block_9_expand_BN (BatchNormalization)             (None, 10, 10, 384)                             1536              N          |
# |                                                                                                                                 |
# | block_9_expand_relu (ReLU)                         (None, 10, 10, 384)                             0                 N          |
# |                                                                                                                                 |
# | block_9_depthwise (DepthwiseConv2D)                (None, 10, 10, 384)                             3456              N          |
# |                                                                                                                                 |
# | block_9_depthwise_BN (BatchNormalization)          (None, 10, 10, 384)                             1536              N          |
# |                                                                                                                                 |
# | block_9_depthwise_relu (ReLU)                      (None, 10, 10, 384)                             0                 N          |
# |                                                                                                                                 |
# | block_9_project (Conv2D)                           (None, 10, 10, 64)                              24576             N          |
# |                                                                                                                                 |
# | block_9_project_BN (BatchNormalization)            (None, 10, 10, 64)                              256               N          |
# |                                                                                                                                 |
# | block_9_add (Add)                                  (None, 10, 10, 64)                              0                 N          |
# |                                                                                                                                 |
# | block_10_expand (Conv2D)                           (None, 10, 10, 384)                             24576             N          |
# |                                                                                                                                 |
# | block_10_expand_BN (BatchNormalization)            (None, 10, 10, 384)                             1536              N          |
# |                                                                                                                                 |
# | block_10_expand_relu (ReLU)                        (None, 10, 10, 384)                             0                 N          |
# |                                                                                                                                 |
# | block_10_depthwise (DepthwiseConv2D)               (None, 10, 10, 384)                             3456              N          |
# |                                                                                                                                 |
# | block_10_depthwise_BN (BatchNormalization)         (None, 10, 10, 384)                             1536              N          |
# |                                                                                                                                 |
# | block_10_depthwise_relu (ReLU)                     (None, 10, 10, 384)                             0                 N          |
# |                                                                                                                                 |
# | block_10_project (Conv2D)                          (None, 10, 10, 96)                              36864             N          |
# |                                                                                                                                 |
# | block_10_project_BN (BatchNormalization)           (None, 10, 10, 96)                              384               N          |
# |                                                                                                                                 |
# | block_11_expand (Conv2D)                           (None, 10, 10, 576)                             55296             N          |
# |                                                                                                                                 |
# | block_11_expand_BN (BatchNormalization)            (None, 10, 10, 576)                             2304              N          |
# |                                                                                                                                 |
# | block_11_expand_relu (ReLU)                        (None, 10, 10, 576)                             0                 N          |
# |                                                                                                                                 |
# | block_11_depthwise (DepthwiseConv2D)               (None, 10, 10, 576)                             5184              N          |
# |                                                                                                                                 |
# | block_11_depthwise_BN (BatchNormalization)         (None, 10, 10, 576)                             2304              N          |
# |                                                                                                                                 |
# | block_11_depthwise_relu (ReLU)                     (None, 10, 10, 576)                             0                 N          |
# |                                                                                                                                 |
# | block_11_project (Conv2D)                          (None, 10, 10, 96)                              55296             N          |
# |                                                                                                                                 |
# | block_11_project_BN (BatchNormalization)           (None, 10, 10, 96)                              384               N          |
# |                                                                                                                                 |
# | block_11_add (Add)                                 (None, 10, 10, 96)                              0                 N          |
# |                                                                                                                                 |
# | block_12_expand (Conv2D)                           (None, 10, 10, 576)                             55296             N          |
# |                                                                                                                                 |
# | block_12_expand_BN (BatchNormalization)            (None, 10, 10, 576)                             2304              N          |
# |                                                                                                                                 |
# | block_12_expand_relu (ReLU)                        (None, 10, 10, 576)                             0                 N          |
# |                                                                                                                                 |
# | block_12_depthwise (DepthwiseConv2D)               (None, 10, 10, 576)                             5184              N          |
# |                                                                                                                                 |
# | block_12_depthwise_BN (BatchNormalization)         (None, 10, 10, 576)                             2304              N          |
# |                                                                                                                                 |
# | block_12_depthwise_relu (ReLU)                     (None, 10, 10, 576)                             0                 N          |
# |                                                                                                                                 |
# | block_12_project (Conv2D)                          (None, 10, 10, 96)                              55296             N          |
# |                                                                                                                                 |
# | block_12_project_BN (BatchNormalization)           (None, 10, 10, 96)                              384               N          |
# |                                                                                                                                 |
# | block_12_add (Add)                                 (None, 10, 10, 96)                              0                 N          |
# |                                                                                                                                 |
# | block_13_expand (Conv2D)                           (None, 10, 10, 576)                             55296             N          |
# |                                                                                                                                 |
# | block_13_expand_BN (BatchNormalization)            (None, 10, 10, 576)                             2304              N          |
# |                                                                                                                                 |
# | block_13_expand_relu (ReLU)                        (None, 10, 10, 576)                             0                 N          |
# |                                                                                                                                 |
# | block_13_pad (ZeroPadding2D)                       (None, 11, 11, 576)                             0                 N          |
# |                                                                                                                                 |
# | block_13_depthwise (DepthwiseConv2D)               (None, 5, 5, 576)                               5184              N          |
# |                                                                                                                                 |
# | block_13_depthwise_BN (BatchNormalization)         (None, 5, 5, 576)                               2304              N          |
# |                                                                                                                                 |
# | block_13_depthwise_relu (ReLU)                     (None, 5, 5, 576)                               0                 N          |
# |                                                                                                                                 |
# | block_13_project (Conv2D)                          (None, 5, 5, 160)                               92160             N          |
# |                                                                                                                                 |
# | block_13_project_BN (BatchNormalization)           (None, 5, 5, 160)                               640               N          |
# |                                                                                                                                 |
# | block_14_expand (Conv2D)                           (None, 5, 5, 960)                               153600            N          |
# |                                                                                                                                 |
# | block_14_expand_BN (BatchNormalization)            (None, 5, 5, 960)                               3840              N          |
# |                                                                                                                                 |
# | block_14_expand_relu (ReLU)                        (None, 5, 5, 960)                               0                 N          |
# |                                                                                                                                 |
# | block_14_depthwise (DepthwiseConv2D)               (None, 5, 5, 960)                               8640              N          |
# |                                                                                                                                 |
# | block_14_depthwise_BN (BatchNormalization)         (None, 5, 5, 960)                               3840              N          |
# |                                                                                                                                 |
# | block_14_depthwise_relu (ReLU)                     (None, 5, 5, 960)                               0                 N          |
# |                                                                                                                                 |
# | block_14_project (Conv2D)                          (None, 5, 5, 160)                               153600            N          |
# |                                                                                                                                 |
# | block_14_project_BN (BatchNormalization)           (None, 5, 5, 160)                               640               N          |
# |                                                                                                                                 |
# | block_14_add (Add)                                 (None, 5, 5, 160)                               0                 N          |
# |                                                                                                                                 |
# | block_15_expand (Conv2D)                           (None, 5, 5, 960)                               153600            N          |
# |                                                                                                                                 |
# | block_15_expand_BN (BatchNormalization)            (None, 5, 5, 960)                               3840              N          |
# |                                                                                                                                 |
# | block_15_expand_relu (ReLU)                        (None, 5, 5, 960)                               0                 N          |
# |                                                                                                                                 |
# | block_15_depthwise (DepthwiseConv2D)               (None, 5, 5, 960)                               8640              N          |
# |                                                                                                                                 |
# | block_15_depthwise_BN (BatchNormalization)         (None, 5, 5, 960)                               3840              N          |
# |                                                                                                                                 |
# | block_15_depthwise_relu (ReLU)                     (None, 5, 5, 960)                               0                 N          |
# |                                                                                                                                 |
# | block_15_project (Conv2D)                          (None, 5, 5, 160)                               153600            N          |
# |                                                                                                                                 |
# | block_15_project_BN (BatchNormalization)           (None, 5, 5, 160)                               640               N          |
# |                                                                                                                                 |
# | block_15_add (Add)                                 (None, 5, 5, 160)                               0                 N          |
# |                                                                                                                                 |
# | block_16_expand (Conv2D)                           (None, 5, 5, 960)                               153600            N          |
# |                                                                                                                                 |
# | block_16_expand_BN (BatchNormalization)            (None, 5, 5, 960)                               3840              N          |
# |                                                                                                                                 |
# | block_16_expand_relu (ReLU)                        (None, 5, 5, 960)                               0                 N          |
# |                                                                                                                                 |
# | block_16_depthwise (DepthwiseConv2D)               (None, 5, 5, 960)                               8640              N          |
# |                                                                                                                                 |
# | block_16_depthwise_BN (BatchNormalization)         (None, 5, 5, 960)                               3840              N          |
# |                                                                                                                                 |
# | block_16_depthwise_relu (ReLU)                     (None, 5, 5, 960)                               0                 N          |
# |                                                                                                                                 |
# | block_16_project (Conv2D)                          (None, 5, 5, 320)                               307200            N          |
# |                                                                                                                                 |
# | block_16_project_BN (BatchNormalization)           (None, 5, 5, 320)                               1280              N          |
# |                                                                                                                                 |
# | Conv_1 (Conv2D)                                    (None, 5, 5, 1280)                              409600            N          |
# |                                                                                                                                 |
# | Conv_1_bn (BatchNormalization)                     (None, 5, 5, 1280)                              5120              N          |
# |                                                                                                                                 |
# | out_relu (ReLU)                                    (None, 5, 5, 1280)                              0                 N          |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  flatten (Flatten)                                    (None, 32000)                                   0                 Y
#
#  dense (Dense)                                        (None, 1024)                                    32769024          Y
#
#  dense_1 (Dense)                                      (None, 85)                                      87125             Y
#
# ===================================================================================================================================
# Total params: 35,114,133
# Trainable params: 32,856,149
# Non-trainable params: 2,257,984
# ___________________________________________________________________________________________________________________________________

# %%
# make compile model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=tf.keras.metrics.SparseCategoricalAccuracy())

# %%
# make early stopping
early_stop=tf.keras.callbacks.EarlyStopping(monitor='val_sparse_categorical_accuracy',min_delta=0,patience=10,verbose=1,mode='auto',restore_best_weights=True)

# make train model
history=model.fit(train,batch_size=None,epochs=10_000,verbose=2,callbacks=[early_stop],
                  validation_split=0,validation_data=valid,shuffle=True)
# Out:
# Epoch 1/10000
# 49/49 - 74s - loss: 8.3896 - sparse_categorical_accuracy: 0.4586 - val_loss: 1.2316 - val_sparse_categorical_accuracy: 0.6754 - 74s/epoch - 2s/step
# Epoch 2/10000
# 49/49 - 54s - loss: 0.5318 - sparse_categorical_accuracy: 0.8539 - val_loss: 0.9961 - val_sparse_categorical_accuracy: 0.7603 - 54s/epoch - 1s/step
# Epoch 3/10000
# 49/49 - 45s - loss: 0.2652 - sparse_categorical_accuracy: 0.9237 - val_loss: 0.9451 - val_sparse_categorical_accuracy: 0.7671 - 45s/epoch - 921ms/step
# Epoch 4/10000
# 49/49 - 46s - loss: 0.1497 - sparse_categorical_accuracy: 0.9649 - val_loss: 0.8272 - val_sparse_categorical_accuracy: 0.8069 - 46s/epoch - 931ms/step
# Epoch 5/10000
# 49/49 - 46s - loss: 0.0760 - sparse_categorical_accuracy: 0.9846 - val_loss: 0.9055 - val_sparse_categorical_accuracy: 0.8032 - 46s/epoch - 935ms/step
# Epoch 6/10000
# 49/49 - 52s - loss: 0.0534 - sparse_categorical_accuracy: 0.9855 - val_loss: 0.8065 - val_sparse_categorical_accuracy: 0.8212 - 52s/epoch - 1s/step
# Epoch 7/10000
# 49/49 - 45s - loss: 0.0386 - sparse_categorical_accuracy: 0.9868 - val_loss: 0.8627 - val_sparse_categorical_accuracy: 0.8144 - 45s/epoch - 917ms/step
# Epoch 8/10000
# 49/49 - 46s - loss: 0.0655 - sparse_categorical_accuracy: 0.9823 - val_loss: 0.8590 - val_sparse_categorical_accuracy: 0.8159 - 46s/epoch - 940ms/step
# Epoch 9/10000
# 49/49 - 46s - loss: 0.0492 - sparse_categorical_accuracy: 0.9862 - val_loss: 0.7752 - val_sparse_categorical_accuracy: 0.8272 - 46s/epoch - 945ms/step
# Epoch 10/10000
# 49/49 - 46s - loss: 0.0197 - sparse_categorical_accuracy: 0.9923 - val_loss: 0.7724 - val_sparse_categorical_accuracy: 0.8302 - 46s/epoch - 944ms/step
# Epoch 11/10000
# 49/49 - 53s - loss: 0.0113 - sparse_categorical_accuracy: 0.9949 - val_loss: 0.7696 - val_sparse_categorical_accuracy: 0.8279 - 53s/epoch - 1s/step
# Epoch 12/10000
# 49/49 - 46s - loss: 0.0115 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.8225 - val_sparse_categorical_accuracy: 0.8332 - 46s/epoch - 944ms/step
# Epoch 13/10000
# 49/49 - 46s - loss: 0.0157 - sparse_categorical_accuracy: 0.9939 - val_loss: 0.7870 - val_sparse_categorical_accuracy: 0.8340 - 46s/epoch - 935ms/step
# Epoch 14/10000
# 49/49 - 45s - loss: 0.0162 - sparse_categorical_accuracy: 0.9952 - val_loss: 0.7880 - val_sparse_categorical_accuracy: 0.8332 - 45s/epoch - 920ms/step
# Epoch 15/10000
# 49/49 - 46s - loss: 0.0225 - sparse_categorical_accuracy: 0.9923 - val_loss: 0.8019 - val_sparse_categorical_accuracy: 0.8249 - 46s/epoch - 943ms/step
# Epoch 16/10000
# 49/49 - 46s - loss: 0.0264 - sparse_categorical_accuracy: 0.9903 - val_loss: 0.9008 - val_sparse_categorical_accuracy: 0.8159 - 46s/epoch - 941ms/step
# Epoch 17/10000
# 49/49 - 52s - loss: 0.0326 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.9695 - val_sparse_categorical_accuracy: 0.7956 - 52s/epoch - 1s/step
# Epoch 18/10000
# 49/49 - 52s - loss: 0.0390 - sparse_categorical_accuracy: 0.9884 - val_loss: 0.9182 - val_sparse_categorical_accuracy: 0.8054 - 52s/epoch - 1s/step
# Epoch 19/10000
# 49/49 - 44s - loss: 0.0298 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.9940 - val_sparse_categorical_accuracy: 0.8062 - 44s/epoch - 906ms/step
# Epoch 20/10000
# 49/49 - 44s - loss: 0.0457 - sparse_categorical_accuracy: 0.9862 - val_loss: 1.1015 - val_sparse_categorical_accuracy: 0.7889 - 44s/epoch - 907ms/step
# Epoch 21/10000
# 49/49 - 45s - loss: 0.0779 - sparse_categorical_accuracy: 0.9775 - val_loss: 1.0988 - val_sparse_categorical_accuracy: 0.7956 - 45s/epoch - 918ms/step
# Epoch 22/10000
# 49/49 - 44s - loss: 0.1371 - sparse_categorical_accuracy: 0.9668 - val_loss: 1.4451 - val_sparse_categorical_accuracy: 0.7686 - 44s/epoch - 906ms/step
# Epoch 23/10000
# Restoring model weights from the end of the best epoch: 13.
# 49/49 - 44s - loss: 0.2630 - sparse_categorical_accuracy: 0.9340 - val_loss: 1.6633 - val_sparse_categorical_accuracy: 0.7273 - 44s/epoch - 904ms/step
# Epoch 23: early stopping

# %%
# see model history (first five epoches)
pd.DataFrame(history.history).head()
# Out:
#        loss  sparse_categorical_accuracy  val_loss  \
# 0  8.389616                     0.458642  1.231597
# 1  0.531775                     0.853878  0.996102
# 2  0.265195                     0.923721  0.945116
# 3  0.149657                     0.964918  0.827169
# 4  0.076030                     0.984551  0.905467
#
#    val_sparse_categorical_accuracy
# 0                         0.675432
# 1                         0.760331
# 2                         0.767092
# 3                         0.806912
# 4                         0.803156

# %%
# see model history (last five epoches)
pd.DataFrame(history.history).tail()
# Out:
#         loss  sparse_categorical_accuracy  val_loss  \
# 18  0.029813                     0.988091  0.993967
# 19  0.045687                     0.986160  1.101466
# 20  0.077870                     0.977470  1.098818
# 21  0.137104                     0.966849  1.445139
# 22  0.263031                     0.934020  1.663250
#
#     val_sparse_categorical_accuracy
# 18                         0.806161
# 19                         0.788881
# 20                         0.795642
# 21                         0.768595
# 22                         0.727273

# %%
# make plot training accuracy and validation accuracy
pd.DataFrame(history.history)[['sparse_categorical_accuracy','val_sparse_categorical_accuracy']].plot(marker='.')# make plot
plt.grid(),plt.title('Training Accuracy'),plt.xlabel('epochs'),plt.ylabel('accuracy')# add grid, title and axis labels
plt.show()

# %%
# make plot training losses and validation losses
pd.DataFrame(history.history)[['loss','val_loss']].plot(marker='.')             # make plot
plt.grid(),plt.title('Training Losses'),plt.xlabel('epochs'),plt.ylabel('loss') # add grid, title and axis labels
plt.show()                                                                      # make plot show

# %%
# evaluate model
results=model.evaluate(test,batch_size=None,verbose="auto",sample_weight=None,return_dict=True)
print('Testing results:',results)
# Out:
# 21/21 [==============================] - 5s 248ms/step - loss: 0.9274 - sparse_categorical_accuracy: 0.8276
# Testing results: {'loss': 0.9274312853813171, 'sparse_categorical_accuracy': 0.8276397585868835}

# %%
# make save model (weights and configuration)
model.save('traffic_sign_classifier',overwrite=True,save_format=None)           # make save
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 52). These functions will not be directly callable after loading.

# %%
# !zip -r -qq "traffic_sign_classifier.zip" "traffic_sign_classifier"             # make zip model
# make auto download model weights
from google.colab import files                                                  # load file class
files.download('traffic_sign_classifier.zip')                                   # download model zip file
