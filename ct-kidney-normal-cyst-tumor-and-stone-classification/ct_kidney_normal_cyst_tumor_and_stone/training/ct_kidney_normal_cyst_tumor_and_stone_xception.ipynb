# %%
# !python -m pip install -qq kaggle

# %%
# %%bash
# mkdir ~/.kaggle                                                                 #
# cp kaggle.json ~/.kaggle/
# chmod 600 ~/.kaggle/kaggle.json
# kaggle datasets download nazmul0087/ct-kidney-dataset-normal-cyst-tumor-and-stone
# unzip -qq "/content/ct-kidney-dataset-normal-cyst-tumor-and-stone.zip"
# mv "CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone" "ct_kidney_dataset"
# mv "ct_kidney_dataset/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone" "CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"
# rm -rf "sample_data" "ct_kidney_dataset"
# mv "CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone" "ct_kidney_dataset"
# Out:
# Downloading ct-kidney-dataset-normal-cyst-tumor-and-stone.zip to /content
# 100%|██████████| 1.52G/1.52G [00:14<00:00, 112MB/s]

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_datasets as tfds
import os
import re
import matplotlib.pyplot as plt

# %%
# load data csv file as dataframe
metadata=pd.read_csv('kidneyData.csv').drop(columns=['Unnamed: 0'])             # load data and drop old indexs
metadata.head()
                                                     # see first five rows
# Out:
#         image_id                                               path   diag  \
# 0  Tumor- (1044)  /content/data/CT KIDNEY DATASET Normal, CYST, ...  Tumor
# 1    Tumor- (83)  /content/data/CT KIDNEY DATASET Normal, CYST, ...  Tumor
# 2   Tumor- (580)  /content/data/CT KIDNEY DATASET Normal, CYST, ...  Tumor
# 3  Tumor- (1701)  /content/data/CT KIDNEY DATASET Normal, CYST, ...  Tumor
# 4  Tumor- (1220)  /content/data/CT KIDNEY DATASET Normal, CYST, ...  Tumor
#
#    target  Class
# 0       3  Tumor
# 1       3  Tumor
# 2       3  Tumor
# 3       3  Tumor
# 4       3  Tumor

# %%
class_labels_dict=metadata.groupby('Class')[['target']].aggregate('mean').astype('uint8').to_dict()['target']
class_labels=class_labels_dict.keys()

# %%
classes=os.listdir('ct_kidney_dataset')                                                  # get all classes names
print('Total classes:',len(classes))                                            # total classes
print('Class names:',classes)                                                   # class names
# clean class names
classes_clean=[re.sub('[^A-Za-z0-9 ]',' ',class_) for class_ in classes]        # remove unwanted characters
classes_clean=[re.sub('[ ]+','_',class_).casefold() for class_ in classes_clean]# replace one or multiple spaces by underscore '_'
print('Cleaned Class names:',classes_clean)                                     # clean class names
# rename class names with clean class names
for old_name,new_name in zip(classes,classes_clean):                            # get old and new class names
  os.rename(os.path.join('ct_kidney_dataset',old_name),os.path.join('ct_kidney_dataset',new_name))# rename with new class names
# get minimum class count ------------------------------------------------------
class_counts:dict=dict()                                                        # get class samples for each class
# get number of files in each class
for class_ in os.listdir('ct_kidney_dataset'):                                           # get class name folder
  class_counts[class_]=len(os.listdir(os.path.join('ct_kidney_dataset',class_)))         # count samples in given class
print('Class counts:',class_counts)                                             # print class counts
minimum_class_count=min(class_counts.values())                                  # get minimum class count
test_split_size:int=int(minimum_class_count*10/100)                             # get test split size
# make train and test directory
os.mkdir('test')                                                                # make directory to store test data
# move 10% of minimum class count from each directory
for class_ in os.listdir('ct_kidney_dataset'):
  os.mkdir(os.path.join('test',class_))                                         # make folder in test directory
  # make move randomly selected images from main to test directory
  for image in np.random.choice(os.listdir(os.path.join('ct_kidney_dataset',class_)),replace=False,size=test_split_size):# get image by image
    os.rename(os.path.join('ct_kidney_dataset',class_,image),os.path.join('test',class_,image))# make move image
os.rename('ct_kidney_dataset','train')                                                   # rename main directory as train
# Out:
# Total classes: 4
# Class names: ['Stone', 'Normal', 'Cyst', 'Tumor']
# Cleaned Class names: ['stone', 'normal', 'cyst', 'tumor']
# Class counts: {'stone': 1377, 'normal': 5077, 'cyst': 3709, 'tumor': 2283}

# %%
# load dataset - train, test and valid
train=tf.keras.utils.image_dataset_from_directory('train',labels='inferred',label_mode='int',class_names=None,color_mode='rgb',
                                                  batch_size=16,image_size=(192,192),shuffle=True,validation_split=0.3,
                                                  interpolation='bilinear',subset='training',seed=8,)
valid=tf.keras.utils.image_dataset_from_directory('train',labels='inferred',label_mode='int',class_names=None,color_mode='rgb',
                                                  batch_size=16,image_size=(192,192),shuffle=True,validation_split=0.3,
                                                  interpolation='bilinear',subset='validation',seed=8,)
test=tf.keras.utils.image_dataset_from_directory('test',labels='inferred',label_mode='int',class_names=None,color_mode='rgb',
                                                 batch_size=16,image_size=(192,192),shuffle=False,validation_split=0.0,
                                                 interpolation='bilinear',subset=None,seed=8,)
print('Total training images:',train.cardinality()*16)
print('Total validation images:',valid.cardinality()*16)
print('Total test images:',test.cardinality()*16)
training_classes:list=train.class_names
valid_classses:list=valid.class_names
test_classes:list=test.class_names
assert training_classes==valid_classses==test_classes,'class count in train, valid and test set is not same'
print('Class names:',training_classes)
# Out:
# Found 11898 files belonging to 4 classes.
# Using 8329 files for training.
# Found 11898 files belonging to 4 classes.
# Using 3569 files for validation.
# Found 548 files belonging to 4 classes.
# Total training images: tf.Tensor(8336, shape=(), dtype=int64)
# Total validation images: tf.Tensor(3584, shape=(), dtype=int64)
# Total test images: tf.Tensor(560, shape=(), dtype=int64)
# Class names: ['cyst', 'normal', 'stone', 'tumor']

# %%
# make plot data training data
for images,labels in train.take(1):break                                        # get a batch of data
images_to_plot:int=6                                                            # number of images to plot
plt.figure(figsize=(15,15))                                                     # figure size
for index in range(images_to_plot):                                             # loop over image index
  plt.subplot(3,3,index+1)                                                      # subplot rows = 3, columns = 3
  plt.imshow(images[index].numpy().astype('uint8'))                             # make plot image
  plt.axis('off')                                                               # make axis off
  plt.title(training_classes[labels[index].numpy()])                            # make add labels as class names
plt.tight_layout()                                                              # adjust layout space
plt.show()                                                                      # make plot show

# %%
print('Maximum pixel values:',tf.reduce_max(images))                            # maximum pixel values in inputs
print('Minimum pixel values:',tf.reduce_min(images))                            # minimum pixel values in inputs
print('Object type of inputs (X):',type(images))                                # input types
print('Data type in inputs (X):',images.dtype)                                  # data type in inputs
print('Object type of outputs (y):',type(labels))                               # output types
print('Data type in outputs (X):',labels.dtype)
# Out:
# Maximum pixel values: tf.Tensor(255.0, shape=(), dtype=float32)
# Minimum pixel values: tf.Tensor(0.0, shape=(), dtype=float32)
# Object type of inputs (X): <class 'tensorflow.python.framework.ops.EagerTensor'>
# Data type in inputs (X): <dtype: 'float32'>
# Object type of outputs (y): <class 'tensorflow.python.framework.ops.EagerTensor'>
# Data type in outputs (X): <dtype: 'int32'>

# %%
# make apply data augmentation to data (add more randomness to data)
# source: https://www.tensorflow.org/tutorials/images/data_augmentation
random_flip=tf.keras.layers.RandomFlip('horizontal_and_vertical',name='random_flip')# random flip layer
random_zoom=tf.keras.layers.RandomZoom(height_factor=0.1,width_factor=0.1,name='random_zoom')# random zoom layer
random_rotate=tf.keras.layers.RandomRotation(0.3,name='random_rotate')          # random rotate layers
random_brightness=tf.keras.layers.RandomBrightness(0.3,value_range=(0.0,255.0),name='random_brightness')# random brightness layer
augmentations=[random_flip,random_zoom,random_rotate,random_brightness]         # make list of data augmentation
# make apply augmentation on training data
for augmentation in augmentations:  train.map(lambda images,labels: (augmentation(images),labels))                # make apply augmentation

# %%
base_model=tf.keras.applications.Xception(include_top=False,weights='imagenet',input_shape=(192,192,3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 0s 0us/step

# %%
inputs=tf.keras.layers.Input(shape=(192,192,3),batch_size=None,name='model_inputs')
model_x=tf.keras.layers.Rescaling(1./255,offset=0.0,name='rescaler')(inputs)
model_x=base_model(model_x)
model_x=tf.keras.layers.Flatten(name='flatten')(model_x)
model_x=tf.keras.layers.Dense(1024,activation='relu')(model_x)
outputs=tf.keras.layers.Dense(len(training_classes),activation='softmax')(model_x)
model=tf.keras.Model(inputs=[inputs],outputs=[outputs],name='xception_model')
model.summary(line_length=120,positions=None,print_fn=None,expand_nested=True,show_trainable=True,layer_range=None)
# Out:
# Model: "xception_model"
# ___________________________________________________________________________________________________________________________________
#  Layer (type)                                         Output Shape                                    Param #           Trainable
# ===================================================================================================================================
#  model_inputs (InputLayer)                            [(None, 192, 192, 3)]                           0                 Y
#
#  rescaler (Rescaling)                                 (None, 192, 192, 3)                             0                 Y
#
#  xception (Functional)                                (None, 6, 6, 2048)                              20861480          Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_1 (InputLayer)                               [(None, 192, 192, 3)]                           0                 Y          |
# |                                                                                                                                 |
# | block1_conv1 (Conv2D)                              (None, 95, 95, 32)                              864               Y          |
# |                                                                                                                                 |
# | block1_conv1_bn (BatchNormalization)               (None, 95, 95, 32)                              128               Y          |
# |                                                                                                                                 |
# | block1_conv1_act (Activation)                      (None, 95, 95, 32)                              0                 Y          |
# |                                                                                                                                 |
# | block1_conv2 (Conv2D)                              (None, 93, 93, 64)                              18432             Y          |
# |                                                                                                                                 |
# | block1_conv2_bn (BatchNormalization)               (None, 93, 93, 64)                              256               Y          |
# |                                                                                                                                 |
# | block1_conv2_act (Activation)                      (None, 93, 93, 64)                              0                 Y          |
# |                                                                                                                                 |
# | block2_sepconv1 (SeparableConv2D)                  (None, 93, 93, 128)                             8768              Y          |
# |                                                                                                                                 |
# | block2_sepconv1_bn (BatchNormalization)            (None, 93, 93, 128)                             512               Y          |
# |                                                                                                                                 |
# | block2_sepconv2_act (Activation)                   (None, 93, 93, 128)                             0                 Y          |
# |                                                                                                                                 |
# | block2_sepconv2 (SeparableConv2D)                  (None, 93, 93, 128)                             17536             Y          |
# |                                                                                                                                 |
# | block2_sepconv2_bn (BatchNormalization)            (None, 93, 93, 128)                             512               Y          |
# |                                                                                                                                 |
# | conv2d (Conv2D)                                    (None, 47, 47, 128)                             8192              Y          |
# |                                                                                                                                 |
# | block2_pool (MaxPooling2D)                         (None, 47, 47, 128)                             0                 Y          |
# |                                                                                                                                 |
# | batch_normalization (BatchNormalization)           (None, 47, 47, 128)                             512               Y          |
# |                                                                                                                                 |
# | add (Add)                                          (None, 47, 47, 128)                             0                 Y          |
# |                                                                                                                                 |
# | block3_sepconv1_act (Activation)                   (None, 47, 47, 128)                             0                 Y          |
# |                                                                                                                                 |
# | block3_sepconv1 (SeparableConv2D)                  (None, 47, 47, 256)                             33920             Y          |
# |                                                                                                                                 |
# | block3_sepconv1_bn (BatchNormalization)            (None, 47, 47, 256)                             1024              Y          |
# |                                                                                                                                 |
# | block3_sepconv2_act (Activation)                   (None, 47, 47, 256)                             0                 Y          |
# |                                                                                                                                 |
# | block3_sepconv2 (SeparableConv2D)                  (None, 47, 47, 256)                             67840             Y          |
# |                                                                                                                                 |
# | block3_sepconv2_bn (BatchNormalization)            (None, 47, 47, 256)                             1024              Y          |
# |                                                                                                                                 |
# | conv2d_1 (Conv2D)                                  (None, 24, 24, 256)                             32768             Y          |
# |                                                                                                                                 |
# | block3_pool (MaxPooling2D)                         (None, 24, 24, 256)                             0                 Y          |
# |                                                                                                                                 |
# | batch_normalization_1 (BatchNormalization)         (None, 24, 24, 256)                             1024              Y          |
# |                                                                                                                                 |
# | add_1 (Add)                                        (None, 24, 24, 256)                             0                 Y          |
# |                                                                                                                                 |
# | block4_sepconv1_act (Activation)                   (None, 24, 24, 256)                             0                 Y          |
# |                                                                                                                                 |
# | block4_sepconv1 (SeparableConv2D)                  (None, 24, 24, 728)                             188672            Y          |
# |                                                                                                                                 |
# | block4_sepconv1_bn (BatchNormalization)            (None, 24, 24, 728)                             2912              Y          |
# |                                                                                                                                 |
# | block4_sepconv2_act (Activation)                   (None, 24, 24, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block4_sepconv2 (SeparableConv2D)                  (None, 24, 24, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block4_sepconv2_bn (BatchNormalization)            (None, 24, 24, 728)                             2912              Y          |
# |                                                                                                                                 |
# | conv2d_2 (Conv2D)                                  (None, 12, 12, 728)                             186368            Y          |
# |                                                                                                                                 |
# | block4_pool (MaxPooling2D)                         (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | batch_normalization_2 (BatchNormalization)         (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | add_2 (Add)                                        (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block5_sepconv1_act (Activation)                   (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block5_sepconv1 (SeparableConv2D)                  (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block5_sepconv1_bn (BatchNormalization)            (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | block5_sepconv2_act (Activation)                   (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block5_sepconv2 (SeparableConv2D)                  (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block5_sepconv2_bn (BatchNormalization)            (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | block5_sepconv3_act (Activation)                   (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block5_sepconv3 (SeparableConv2D)                  (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block5_sepconv3_bn (BatchNormalization)            (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | add_3 (Add)                                        (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block6_sepconv1_act (Activation)                   (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block6_sepconv1 (SeparableConv2D)                  (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block6_sepconv1_bn (BatchNormalization)            (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | block6_sepconv2_act (Activation)                   (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block6_sepconv2 (SeparableConv2D)                  (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block6_sepconv2_bn (BatchNormalization)            (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | block6_sepconv3_act (Activation)                   (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block6_sepconv3 (SeparableConv2D)                  (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block6_sepconv3_bn (BatchNormalization)            (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | add_4 (Add)                                        (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block7_sepconv1_act (Activation)                   (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block7_sepconv1 (SeparableConv2D)                  (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block7_sepconv1_bn (BatchNormalization)            (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | block7_sepconv2_act (Activation)                   (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block7_sepconv2 (SeparableConv2D)                  (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block7_sepconv2_bn (BatchNormalization)            (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | block7_sepconv3_act (Activation)                   (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block7_sepconv3 (SeparableConv2D)                  (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block7_sepconv3_bn (BatchNormalization)            (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | add_5 (Add)                                        (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block8_sepconv1_act (Activation)                   (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block8_sepconv1 (SeparableConv2D)                  (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block8_sepconv1_bn (BatchNormalization)            (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | block8_sepconv2_act (Activation)                   (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block8_sepconv2 (SeparableConv2D)                  (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block8_sepconv2_bn (BatchNormalization)            (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | block8_sepconv3_act (Activation)                   (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block8_sepconv3 (SeparableConv2D)                  (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block8_sepconv3_bn (BatchNormalization)            (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | add_6 (Add)                                        (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block9_sepconv1_act (Activation)                   (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block9_sepconv1 (SeparableConv2D)                  (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block9_sepconv1_bn (BatchNormalization)            (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | block9_sepconv2_act (Activation)                   (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block9_sepconv2 (SeparableConv2D)                  (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block9_sepconv2_bn (BatchNormalization)            (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | block9_sepconv3_act (Activation)                   (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block9_sepconv3 (SeparableConv2D)                  (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block9_sepconv3_bn (BatchNormalization)            (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | add_7 (Add)                                        (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block10_sepconv1_act (Activation)                  (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block10_sepconv1 (SeparableConv2D)                 (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block10_sepconv1_bn (BatchNormalization)           (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | block10_sepconv2_act (Activation)                  (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block10_sepconv2 (SeparableConv2D)                 (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block10_sepconv2_bn (BatchNormalization)           (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | block10_sepconv3_act (Activation)                  (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block10_sepconv3 (SeparableConv2D)                 (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block10_sepconv3_bn (BatchNormalization)           (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | add_8 (Add)                                        (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block11_sepconv1_act (Activation)                  (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block11_sepconv1 (SeparableConv2D)                 (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block11_sepconv1_bn (BatchNormalization)           (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | block11_sepconv2_act (Activation)                  (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block11_sepconv2 (SeparableConv2D)                 (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block11_sepconv2_bn (BatchNormalization)           (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | block11_sepconv3_act (Activation)                  (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block11_sepconv3 (SeparableConv2D)                 (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block11_sepconv3_bn (BatchNormalization)           (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | add_9 (Add)                                        (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block12_sepconv1_act (Activation)                  (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block12_sepconv1 (SeparableConv2D)                 (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block12_sepconv1_bn (BatchNormalization)           (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | block12_sepconv2_act (Activation)                  (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block12_sepconv2 (SeparableConv2D)                 (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block12_sepconv2_bn (BatchNormalization)           (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | block12_sepconv3_act (Activation)                  (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block12_sepconv3 (SeparableConv2D)                 (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block12_sepconv3_bn (BatchNormalization)           (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | add_10 (Add)                                       (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block13_sepconv1_act (Activation)                  (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block13_sepconv1 (SeparableConv2D)                 (None, 12, 12, 728)                             536536            Y          |
# |                                                                                                                                 |
# | block13_sepconv1_bn (BatchNormalization)           (None, 12, 12, 728)                             2912              Y          |
# |                                                                                                                                 |
# | block13_sepconv2_act (Activation)                  (None, 12, 12, 728)                             0                 Y          |
# |                                                                                                                                 |
# | block13_sepconv2 (SeparableConv2D)                 (None, 12, 12, 1024)                            752024            Y          |
# |                                                                                                                                 |
# | block13_sepconv2_bn (BatchNormalization)           (None, 12, 12, 1024)                            4096              Y          |
# |                                                                                                                                 |
# | conv2d_3 (Conv2D)                                  (None, 6, 6, 1024)                              745472            Y          |
# |                                                                                                                                 |
# | block13_pool (MaxPooling2D)                        (None, 6, 6, 1024)                              0                 Y          |
# |                                                                                                                                 |
# | batch_normalization_3 (BatchNormalization)         (None, 6, 6, 1024)                              4096              Y          |
# |                                                                                                                                 |
# | add_11 (Add)                                       (None, 6, 6, 1024)                              0                 Y          |
# |                                                                                                                                 |
# | block14_sepconv1 (SeparableConv2D)                 (None, 6, 6, 1536)                              1582080           Y          |
# |                                                                                                                                 |
# | block14_sepconv1_bn (BatchNormalization)           (None, 6, 6, 1536)                              6144              Y          |
# |                                                                                                                                 |
# | block14_sepconv1_act (Activation)                  (None, 6, 6, 1536)                              0                 Y          |
# |                                                                                                                                 |
# | block14_sepconv2 (SeparableConv2D)                 (None, 6, 6, 2048)                              3159552           Y          |
# |                                                                                                                                 |
# | block14_sepconv2_bn (BatchNormalization)           (None, 6, 6, 2048)                              8192              Y          |
# |                                                                                                                                 |
# | block14_sepconv2_act (Activation)                  (None, 6, 6, 2048)                              0                 Y          |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  flatten (Flatten)                                    (None, 73728)                                   0                 Y
#
#  dense (Dense)                                        (None, 1024)                                    75498496          Y
#
#  dense_1 (Dense)                                      (None, 4)                                       4100              Y
#
# ===================================================================================================================================
# Total params: 96,364,076
# Trainable params: 96,309,548
# Non-trainable params: 54,528
# ___________________________________________________________________________________________________________________________________

# %%
# make compile model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),loss=tf.keras.losses.SparseCategoricalCrossentropy(),              metrics=tf.keras.metrics.SparseCategoricalAccuracy())

# %%
# make early stopping
early_stop=tf.keras.callbacks.EarlyStopping(monitor='val_sparse_categorical_accuracy',min_delta=0,patience=10,verbose=1,mode='auto',restore_best_weights=True)

# make train model
history=model.fit(train,batch_size=16,epochs=10_000,verbose=2,callbacks=[early_stop],validation_split=0,validation_data=valid,
                  shuffle=True)
# Out:
# Epoch 1/10000
# 521/521 - 161s - loss: 0.8479 - sparse_categorical_accuracy: 0.6878 - val_loss: 0.7376 - val_sparse_categorical_accuracy: 0.8083 - 161s/epoch - 309ms/step
# Epoch 2/10000
# 521/521 - 115s - loss: 0.1274 - sparse_categorical_accuracy: 0.9652 - val_loss: 0.1239 - val_sparse_categorical_accuracy: 0.9689 - 115s/epoch - 221ms/step
# Epoch 3/10000
# 521/521 - 115s - loss: 0.0911 - sparse_categorical_accuracy: 0.9768 - val_loss: 0.5052 - val_sparse_categorical_accuracy: 0.9112 - 115s/epoch - 221ms/step
# Epoch 4/10000
# 521/521 - 116s - loss: 0.3605 - sparse_categorical_accuracy: 0.9274 - val_loss: 10222.3457 - val_sparse_categorical_accuracy: 0.2057 - 116s/epoch - 223ms/step
# Epoch 5/10000
# 521/521 - 116s - loss: 0.3116 - sparse_categorical_accuracy: 0.9043 - val_loss: 0.0625 - val_sparse_categorical_accuracy: 0.9821 - 116s/epoch - 222ms/step
# Epoch 6/10000
# 521/521 - 116s - loss: 0.0532 - sparse_categorical_accuracy: 0.9851 - val_loss: 0.0437 - val_sparse_categorical_accuracy: 0.9857 - 116s/epoch - 222ms/step
# Epoch 7/10000
# 521/521 - 115s - loss: 0.0660 - sparse_categorical_accuracy: 0.9848 - val_loss: 0.0909 - val_sparse_categorical_accuracy: 0.9667 - 115s/epoch - 221ms/step
# Epoch 8/10000
# 521/521 - 116s - loss: 0.0400 - sparse_categorical_accuracy: 0.9896 - val_loss: 6.8456e-04 - val_sparse_categorical_accuracy: 1.0000 - 116s/epoch - 223ms/step
# Epoch 9/10000
# 521/521 - 115s - loss: 0.0776 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.1025 - val_sparse_categorical_accuracy: 0.9630 - 115s/epoch - 222ms/step
# Epoch 10/10000
# 521/521 - 123s - loss: 0.0898 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.4071 - val_sparse_categorical_accuracy: 0.9442 - 123s/epoch - 236ms/step
# Epoch 11/10000
# 521/521 - 117s - loss: 0.1859 - sparse_categorical_accuracy: 0.9669 - val_loss: 0.1962 - val_sparse_categorical_accuracy: 0.9569 - 117s/epoch - 224ms/step
# Epoch 12/10000
# 521/521 - 115s - loss: 0.1865 - sparse_categorical_accuracy: 0.9649 - val_loss: 0.1271 - val_sparse_categorical_accuracy: 0.9717 - 115s/epoch - 221ms/step
# Epoch 13/10000
# 521/521 - 123s - loss: 0.1555 - sparse_categorical_accuracy: 0.9749 - val_loss: 0.0260 - val_sparse_categorical_accuracy: 0.9913 - 123s/epoch - 236ms/step
# Epoch 14/10000
# 521/521 - 116s - loss: 0.0113 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.1125 - val_sparse_categorical_accuracy: 0.9737 - 116s/epoch - 222ms/step
# Epoch 15/10000
# 521/521 - 115s - loss: 0.0760 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.2549 - val_sparse_categorical_accuracy: 0.9330 - 115s/epoch - 221ms/step
# Epoch 16/10000
# 521/521 - 115s - loss: 0.2026 - sparse_categorical_accuracy: 0.9804 - val_loss: 0.0123 - val_sparse_categorical_accuracy: 0.9966 - 115s/epoch - 221ms/step
# Epoch 17/10000
# 521/521 - 115s - loss: 0.0303 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0184 - val_sparse_categorical_accuracy: 0.9950 - 115s/epoch - 220ms/step
# Epoch 18/10000
# Restoring model weights from the end of the best epoch: 8.
# 521/521 - 116s - loss: 0.0083 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0046 - val_sparse_categorical_accuracy: 0.9992 - 116s/epoch - 223ms/step
# Epoch 18: early stopping

# %%
# see model history (first five epoches)
pd.DataFrame(history.history).head()
# Out:
#        loss  sparse_categorical_accuracy      val_loss  \
# 0  0.847939                     0.687838      0.737649
# 1  0.127444                     0.965182      0.123946
# 2  0.091068                     0.976828      0.505201
# 3  0.360493                     0.927362  10222.345703
# 4  0.311553                     0.904310      0.062526
#
#    val_sparse_categorical_accuracy
# 0                         0.808350
# 1                         0.968899
# 2                         0.911180
# 3                         0.205660
# 4                         0.982068

# %%
# make plot training accuracy and validation accuracy
pd.DataFrame(history.history)[['sparse_categorical_accuracy','val_sparse_categorical_accuracy']].plot(marker='.')# make plot
plt.grid(),plt.title('Training Accuracy'),plt.xlabel('epochs'),plt.ylabel('accuracy')# add grid, title and axis labels
plt.show()                                                                      # make plot showv

# %%
# make plot training losses and validation losses
pd.DataFrame(history.history)[['loss','val_loss']].plot(marker='.')             # make plot
plt.grid(),plt.title('Training Losses'),plt.xlabel('epochs'),plt.ylabel('loss') # add grid, title and axis labels
plt.show()                                                                      # make plot show

# %%
# evaluate model
results=model.evaluate(test,batch_size=None,verbose="auto",sample_weight=None,return_dict=True)
print('Testing results:',results)                                               # make print results
# Out:
# 35/35 [==============================] - 4s 106ms/step - loss: 0.0011 - sparse_categorical_accuracy: 1.0000
# Testing results: {'loss': 0.0011146010365337133, 'sparse_categorical_accuracy': 1.0}

# %%
# make save model (weights and configuration)
model.save('ct_kidney_normal_cyst_tumor_and_stone',overwrite=True,save_format=None)               # make save
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 40). These functions will not be directly callable after loading.

# %%
# !zip -r -qq "ct_kidney_normal_cyst_tumor_and_stone.zip" "ct_kidney_normal_cyst_tumor_and_stone"                     # make zip model
# make auto download model weights
from google.colab import files                                                  # load file class
files.download('ct_kidney_normal_cyst_tumor_and_stone.zip')                                       # download model zip file
